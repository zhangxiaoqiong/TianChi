# %%
import pandas as pd



import zipfile

test_zip = zipfile.ZipFile('../data/Antai_AE_round2_test_20190813.zip')
test_df = pd.read_csv(test_zip.open('Antai_AE_round2_test_20190813.csv'))
print(test_df.shape[0])
test_df.head()

train_zip = zipfile.ZipFile('../data/Antai_AE_round2_train_20190813.zip')
# item_zip = zipfile.ZipFile('../data/Antai_AE_round1_item_attr_20190626.zip') 
print(train_zip.namelist())
# print(item_zip.namelist())
train = train_zip.open('Antai_AE_round2_train_20190813.csv')
# item = item_zip.open('Antai_AE_round1_item_attr_20190626.csv')

train_df = pd.read_csv(train)
# item_df = pd.read_csv(item)
# Out:
# 853825
# ['Antai_AE_round2_train_20190813.csv']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'buyer_country_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-30819c70657c> in <module>
#      20 # item_df = pd.read_csv(item)
#      21
# ---> 22 train_yy = train_df[train_df['buyer_country_id']=='yy']
#      23 train_yy.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'buyer_country_id'

# %%
train_df.head()
# Out:
#   country_id  buyer_admin_id  item_id             log_time  irank  buy_flag
# 0         xx               1     7554  2018-04-19 10:59:56     79         0
# 1         xx               1     7937  2018-04-19 11:17:45     62         0
# 2         xx               1     7544  2018-04-18 22:19:30     81         0
# 3         xx               1     7559  2018-04-18 22:15:27     82         0
# 4         xx               1     7554  2018-04-19 11:28:34     46         0

# %%
train_yy = train_df[train_df['country_id']=='yy']
train_yy.head()
# Out:
#     country_id  buyer_admin_id  item_id             log_time  irank  buy_flag
# 373         yy              10  8918478  2018-04-26 11:30:22      4         0
# 374         yy              10  8918478  2018-04-25 22:59:39      5         0
# 375         yy              10  8646163  2018-04-25 21:41:33      6         0
# 376         yy              10  3484283  2018-04-23 14:59:31      8         0
# 377         yy              10   268538  2018-04-27 14:54:55      3         0

# %%
# 历史购买记录
tmp = test_df[test_df['irank']<=31].sort_values(by=['country_id','buyer_admin_id','irank'])[['buyer_admin_id','item_id','irank']]
tmp.head()
# Out:
#         buyer_admin_id  item_id  irank
# 597323              86  9145597      2
# 597274              86  3706121      3
# 597293              86  8352620      4
# 597294              86  8352620      5
# 597198              86  7706295      6

# %%
tmp2 = pd.DataFrame(tmp.groupby(['buyer_admin_id','item_id']).size(),columns=['cnt']).sort_values('cnt',ascending=False).groupby(['buyer_admin_id']).head(10).reset_index().sort_values(['buyer_admin_id','cnt'],ascending=False)

# %%
tmp2.head()
# Out:
#        buyer_admin_id  item_id  cnt
# 6517           626421  6785359    4
# 29922          626421  7982463    2
# 35528          626421  7253682    2
# 35565          626421  6916804    2
# 35577          626421  4005479    2

# %%
# 热销商品
hot_item_30 = pd.DataFrame(pd.concat([test_df,train_yy]).groupby(['item_id']).size(),columns=['cnt']).sort_values('cnt',ascending=False)[:30]
hot_item_30
# Out:
#             cnt
# item_id
# 8605056  181035
# 2155121  172700
# 3566108   82110
# 3654833   52414
# 3028061   41457
# 5019629   32810
# 4788322   29132
# 3490283   23615
# 8007146   12526
# 2084012   12121
# 7088738   11364
# 1143625   11288
# 5154021   10900
# 3211144   10580
# 8661962    7953
# 960051     6644
# 1286746    6325
# 6857227    5618
# 4893358    5570
# 4167486    5566
# 2389426    5013
# 6821109    4735
# 1594316    4723
# 5741467    3832
# 6717640    3378
# 1665201    3033
# 6631581    2936
# 8104573    2496
# 2269806    2378
# 5345072    2356

# %%
# train_yy['create_order_time'] = train_yy.create_order_time.apply(lambda x:pd.to_datetime(x))
# train_yy['hour'] = train_yy['create_order_time'].dt.hour
# train_yy['date'] = train_yy['create_order_time'].dt.day
# train_yy['month'] = train_yy['create_order_time'].dt.month
# train_yy['year'] = train_yy['create_order_time'].dt.year
# train_yy['month-date'] = train_yy.month.astype(str)+'-'+train_yy.date.astype(str)
# train_yy['count'] = 1
# train_yy['dayofweek'] = train_yy['create_order_time'].dt.dayofweek
# train_yy['isweekend'] = train_yy['dayofweek'].apply(lambda x:0 if x<5 else 1)
# train_yy.head()

# test_df['create_order_time'] = test_df.create_order_time.apply(lambda x:pd.to_datetime(x))
# test_df['hour'] = test_df['create_order_time'].dt.hour
# test_df['date'] = test_df['create_order_time'].dt.day
# test_df['month'] = test_df['create_order_time'].dt.month
# test_df['year'] = test_df['create_order_time'].dt.year
# test_df['count'] = 1
# test_df['month-date'] = test_df.month.astype(str)+'-'+test_df.date.astype(str)
# test_df['dayofweek'] = test_df['create_order_time'].dt.dayofweek
# test_df['isweekend'] = test_df['dayofweek'].apply(lambda x:0 if x<5 else 1)

# %%
import pickle

with open('usercf_pred_round2.pkl', 'rb') as f:
    usercf_pred = pickle.load(f)

# with open('itemcf_pred.pkl', 'rb') as f:
#     itemcf_pred = pickle.load(f)

# %%
result = usercf_pred.predict()
result_df = pd.DataFrame(result,columns=['buyer_admin_id','rec_items'])
result_df['rec_items'] = result_df.rec_items.apply(lambda x:[i[0] for i in x])
result_df['len'] = result_df.rec_items.apply(lambda x:len(x))
result_df
# Out:
# Predict start...
# recommended for 0 users
# recommended for 500 users
# recommended for 1000 users
# recommended for 1500 users
# recommended for 2000 users
# recommended for 2500 users
# recommended for 3000 users
# recommended for 3500 users
# recommended for 4000 users
# recommended for 4500 users
# recommended for 5000 users
# recommended for 5500 users
# recommended for 6000 users
# recommended for 6500 users
# recommended for 7000 users
# recommended for 7500 users
# recommended for 8000 users
# recommended for 8500 users
# recommended for 9000 users
# recommended for 9500 users
# recommended for 10000 users
# recommended for 10500 users
# recommended for 11000 users
# Predict end...
#        buyer_admin_id                                          rec_items  len
# 0             1061132  [1992350, 1207574, 189045, 11271996, 1516143, ...   30
# 1             1081430  [4109174, 822359, 9932432, 10184371, 11565882,...   30
# 2             1918135  [10546322, 2724688, 3239694, 5939557, 6079606,...   30
# 3              103277  [7563496, 3993974, 7481939, 10743206, 7785543,...   30
# 4             1957158  [1214872, 1397346, 6766255, 4955926, 5702107, ...   30
# 5             1376989  [9972220, 11790053, 8694133, 410019, 1551855, ...   30
# 6             1563046  [2434940, 8516922, 10035229, 8300510, 7068791,...   30
# 7             1280264  [3866632, 9388436, 11545249, 5133006, 695628, ...   28
# 8              104145  [1433894, 3197976, 5362349, 1236358, 1291401, ...   30
# 9              850637  [7017123, 10251187, 10622895, 10686858, 119543...   30
# 10            1135064  [10433903, 8099239, 10300735, 10492522, 108251...   30
# 11            2302927  [7521360, 3375401, 2641569, 2620657, 5191840, ...   30
# 12            1152117  [5973981, 7698995, 5786972, 9788190, 10104079,...   30
# 13             570640  [9299908, 2392165, 10491948, 7370949, 269849, ...   30
# 14            1917676  [6423473, 4976805, 5485826, 6381790, 11980433,...   30
# 15            1944372  [10175288, 8685503, 758341, 2393188, 4097780, ...   30
# 16             235457  [12314621, 12177522, 11677603, 4792153, 575401...   30
# 17            1746023  [4797146, 7118512, 12816323, 8368304, 12406203...   30
# 18             406801  [10516392, 1727672, 283107, 4522268, 8141361, ...   30
# 19             230941  [6783037, 526826, 3575829, 2318992, 4937239, 8...   30
# 20            1553497  [7663592, 9535410, 10151922, 10156269, 480658,...   30
# 21             982049  [625121, 625186, 10192310, 7350995, 3039739, 8...   30
# 22            1000927  [8920282, 11375859, 10529296, 11236113, 129789...   30
# 23             730501  [9023224, 6619730, 9161396, 3591180, 6194866, ...   30
# 24             135882  [6457140, 10176518, 9461975, 7979097, 1244150,...   30
# 25             653027  [10060924, 5668704, 2946480, 4658641, 9604575,...   30
# 26            2161973  [9756464, 9973016, 1196016, 10353218, 10883836...   30
# 27            1594372  [11982814, 13035167, 5135820, 9974770, 1047071...   30
# 28             723249  [5553235, 480325, 4868643, 7550926, 9064398, 1...   30
# 29             503825  [11932296, 8815059, 12577021, 11526051, 249217...   30
# ...               ...                                                ...  ...
# 11368         1764504  [2249889, 5777955, 8525615, 2395805, 5901899, ...   30
# 11369         2203284  [1302947, 9560030, 8869187, 6161792, 9359967, ...   30
# 11370         1128243  [8269599, 9567033, 12152275, 9259141, 2107553,...   30
# 11371          847003  [10140500, 10752801, 6926374, 8249320, 9256396...   30
# 11372         2053089  [2307482, 7393913, 1761912, 3547573, 6684037, ...   30
# 11373         1439342  [12093615, 10025910, 3220756, 3850628, 7155403...   30
# 11374         2212230  [6025215, 9907121, 5726997, 2133349, 2925223, ...   29
# 11375          305285  [8195907, 11715056, 541572, 9133572, 10072371,...   30
# 11376          994361  [6497924, 8834769, 1261389, 11291525, 1891295,...   30
# 11377          960146  [11526051, 11412401, 10126085, 1695358, 305306...   30
# 11378         2179759  [3334215, 4536110, 1994006, 2972034, 5534385, ...   30
# 11379         1785549  [2138353, 8837122, 8117410, 6689674, 11148805,...   30
# 11380         2134165  [11538073, 2541425, 5432024, 11028413, 6129840...   30
# 11381         2145746  [8422914, 9775459, 3159240, 4880617, 1857878, ...   30
# 11382          478657  [4396852, 3037124, 1755044, 2975295, 3569752, ...   30
# 11383         1775754  [6025215, 3362266, 9907121, 7473388, 3625959, ...   30
# 11384          748015  [6663274, 12607973, 602156, 1234973, 3059563, ...   30
# 11385          394913                                                 []    0
# 11386          227724  [11845247, 2132560, 7977628, 8200028, 2927321,...   30
# 11387         1283974  [9897114, 6318438, 12543540, 319264, 651168, 5...   30
# 11388          385591  [372521, 2863365, 3762803, 3764814, 6717763, 5...   30
# 11389          524369  [4848097, 7471819, 5063581, 5300877, 9872494, ...   30
# 11390         1688905  [11201409, 2156012, 5445745, 8069568, 8647480,...   30
# 11391         2361324  [3140148, 620653, 1271763, 7533238, 1013112, 6...   30
# 11392         1931205  [9354413, 1427684, 3514289, 4394247, 4947024, ...   30
# 11393          419958  [1291401, 268820, 2393398, 2895381, 3025407, 3...   30
# 11394         1242965  [6188307, 384877, 426384, 1194558, 1197459, 21...   30
# 11395          962939  [7151390, 8297443, 6025215, 7661956, 3096187, ...   30
# 11396         1243416  [7720560, 1666365, 7634786, 1563814, 1937716, ...   30
# 11397         2150916  [5064674, 12037837, 5378739, 8511839, 9760979,...   30
#
# [11398 rows x 3 columns]

# %% [markdown]
# # 组合候选集

# %%
import numpy as np



result = []

hot_lst = hot_item_30[:3].index.values.tolist()
for idx,obj in rec_result.iterrows():
    lst = [int(x) for x in obj.values.tolist() if str(x) != 'nan']
    new_lst = list(set(lst))
    new_lst.sort(key=lst.index)
    usercf_lst = result_df[result_df['buyer_admin_id']==idx]['rec_items'].values.tolist()[0]
    rec_set = new_lst+hot_lst+usercf_lst
#     print(rec_set)
    new_rec_set = list(set(rec_set))
    new_rec_set.sort(key=rec_set.index)
    
    if len(new_rec_set)<30:
        new_rec_set = new_rec_set+hot_item_30[3:].index.values.tolist()
    result.append([idx]+new_rec_set)
    
result = pd.DataFrame(result)
result
# Out:
#              0         1         2         3         4         5         6   \
# 0           152   8410857   7937154   8472223   4016066   9891513   8064216
# 1           282  11721802   7665423  10808393  11310708    623582   6547607
# 2           321   1461800   7379845   9243286    627849   5000759  11774753
# 3           809   2347616   5707010   6339286   5492003   1207574   2262443
# 4           870  11382694   5999244   6611583   7412272   4343647   5546383
# 5          2410   1991652   3010258   8734237   5529566  12328639   8829154
# 6          2956   7116759   8778275   5039457   5071633   9105860   1866761
# 7          3866   3738221   8326767   3366910   9638971  12222697   9796213
# 8          7277  11977450   8343022  10813894  11826481    465594  11550594
# 9          7944  10039927  11659460   7598016   9607731   9555054   4280956
# 10         8192   1306627   4538161   9715746   6857974   9846407   3132866
# 11         8408   9988978   4244544    665393   1195177   1192063    665359
# 12         8464     70466   2914396   2686621   2094230   4157502   2076583
# 13         8637   5639030   8910564   5703905   7334003   8693860  11359278
# 14         8760   5813336   8940662  11075083   4184067   7195147  11717821
# 15         9015   3703072   2775264     18284    924117   1222930   6268272
# 16         9035   5831736   1527698   7432186   8260171   2307115   1414382
# 17         9079    153030   7886311   2203597   4376203   2341287   3964013
# 18        10146   1239063  11493702   3261925   5139229  10832838   2856736
# 19        10836   4218750     59243   4945981    764094    336653   8094014
# 20        11092   6017984   8057645   2969882   8545184    519838   9802330
# 21        12072   1434548  10318396   3261925   6029609   5145720   8297580
# 22        13571   2368260    488153   6680629    450460    495494   1741609
# 23        13851   2583077    188395   2089807   1926597   1917001   1913880
# 24        14685   3625865   9765458   2476527   1927238   4691607   9888588
# 25        14757   2563363   6268181   1474959   8460299   1040334   4528851
# 26        15114   2466013   7064738   7063375  12407710   4173879   7145390
# 27        15195   9916576  10069486  11426762  11557841    979922   8768039
# 28        17068   7386561  12101505  11341806  11948261   4578167   4790754
# 29        17141  10424369   2211474   5137224    807187   8889646   9354704
# ...         ...       ...       ...       ...       ...       ...       ...
# 11368  13008196  11422157  11422157  11422157  11422157  11422157  11422157
# 11369  13024265   5820727  12303807  11730821   7806166   3920932   7720538
# 11370  13024323   9958307  10224561   5285377  11078733    508272  11717821
# 11371  13024369  10677730   8225052   9885717  10130173   3312405  11708409
# 11372  13025072   2241981   7829553  11528914  10161164   7650488   3025084
# 11373  13025986   7548364  11716597  10252830   5739415   9520867   2885471
# 11374  13026568   6195597   6195597   6195597   6195597   6195597   6195597
# 11375  13027356   7550184   9478701   7027025  12631443  12474522   6071521
# 11376  13027430   5181424   2822821    862201   5867257     61817    228559
# 11377  13028759   2092745  11198066   3612060   2006166    669545   6418543
# 11378  13028937   6408695   3092992   1509553   6278237   7805265   2744603
# 11379  13028976   9326463   5516858   1982301   5857431   1290259  10602651
# 11380  13029399   8547587   8547587   8547587   8547587   8547587   8547587
# 11381  13029522  10047489   7642328  12915569   1948215   5738940   9711211
# 11382  13029742   4629356   6462197   2236345   1006260   5650268   1205870
# 11383  13029924  10952271   4886901  11672262  11977196   1563814   5823501
# 11384  13029976   3121849    347955   2989407   2488092   1222225    941515
# 11385  13030926   2742001   6677984   5056744   9014194  10126333    945275
# 11386  13032038   6455563   1042927    779820   3760021   6495186   3903709
# 11387  13034116   1422506   9507238   4597001   1750657  10815434  10782889
# 11388  13035742   2766726   2766726   2766726   2766726   2766726   2766726
# 11389  13037285   5311193   4424159   3619538   4160229  11216403   4708788
# 11390  13037296   6586041   8457004   8755974   6121134   8532333  11717821
# 11391  13038422  10622510  10622510  10622510  10622510  10622510  10622510
# 11392  13039625   6199491   6371563    335237   9009201   6662644   4522369
# 11393  13041046   4465563   4433564   6466730    173060    173140   4987070
# 11394  13041581   7168968   9669996  10159313   7027641   5447793   6491935
# 11395  13044048   9052525  11680535     63066   2447752  11124939  11717821
# 11396  13046354  10391871   7945295   7100322   9556217   9776214  12400852
# 11397  13046601   5619538   5619538   5619538   5619538   5619538   5619538
#
#              7         8         9   ...         56       57        58  \
# 0       8351840  11717821  11140901  ...        NaN      NaN       NaN
# 1       2605373    688799  10517456  ...        NaN      NaN       NaN
# 2      10932288   4813286   9816501  ...        NaN      NaN       NaN
# 3      11717821  11140901   5595070  ...        NaN      NaN       NaN
# 4       3432696   9589237   6163411  ...        NaN      NaN       NaN
# 5      11536411   6594315  12182628  ...        NaN      NaN       NaN
# 6       7644819   1284838    745619  ...        NaN      NaN       NaN
# 7      10241163   6240908  12035835  ...        NaN      NaN       NaN
# 8       2354126  12543036  12226234  ...        NaN      NaN       NaN
# 9       9089404   6884658   6795431  ...        NaN      NaN       NaN
# 10       250407   9631903   2972034  ...        NaN      NaN       NaN
# 11     13035792   4502347  10242192  ...        NaN      NaN       NaN
# 12      2093281   4589918   8941084  ...        NaN      NaN       NaN
# 13       251404  11717821  11140901  ...        NaN      NaN       NaN
# 14     11140901   5595070    596269  ...        NaN      NaN       NaN
# 15      5300682  11717821  11140901  ...        NaN      NaN       NaN
# 16     11717821  11140901   5595070  ...        NaN      NaN       NaN
# 17      1274512   4403361  11733620  ...        NaN      NaN       NaN
# 18      3057411  11717821  11140901  ...        NaN      NaN       NaN
# 19      5162355    988711   5320360  ...        NaN      NaN       NaN
# 20      7580109   6452394    426384  ...        NaN      NaN       NaN
# 21     11290885   9485505  11717821  ...        NaN      NaN       NaN
# 22     11717821  11140901   5595070  ...        NaN      NaN       NaN
# 23      2085920  11717821  11140901  ...        NaN      NaN       NaN
# 24      1874005  11717821  11140901  ...        NaN      NaN       NaN
# 25        25436   3475210   8869549  ...        NaN      NaN       NaN
# 26      6188539  10922386  10354543  ...        NaN      NaN       NaN
# 27      3335895   3991030   3216850  ...        NaN      NaN       NaN
# 28      5728775   4018668  10283527  ...        NaN      NaN       NaN
# 29       196193   4696797  11689271  ...        NaN      NaN       NaN
# ...         ...       ...       ...  ...        ...      ...       ...
# 11368  11422157  11422157  11422157  ...        NaN      NaN       NaN
# 11369   9861363   8517264    766240  ...        NaN      NaN       NaN
# 11370  11140901   5595070    351108  ...        NaN      NaN       NaN
# 11371   9838377  13001397   7828425  ...        NaN      NaN       NaN
# 11372   9352298   2256656   9688536  ...        NaN      NaN       NaN
# 11373   7173733  11717821  11140901  ...        NaN      NaN       NaN
# 11374   6195597   6195597   6195597  ...        NaN      NaN       NaN
# 11375   8856789  11745725  11717821  ...        NaN      NaN       NaN
# 11376  11277872  10664121   1666832  ...        NaN      NaN       NaN
# 11377  11550263  11585585  10462842  ...        NaN      NaN       NaN
# 11378  11717821  11140901   5595070  ...        NaN      NaN       NaN
# 11379   4852733   8777086   6504380  ...        NaN      NaN       NaN
# 11380   8547587   8547587   8547587  ...        NaN      NaN       NaN
# 11381   4350575  10426966   9149733  ...        NaN      NaN       NaN
# 11382  11857149   3500888   8768979  ...  6283922.0  26551.0  112389.0
# 11383   8421677  12999448  11739293  ...        NaN      NaN       NaN
# 11384   2524958   1396531  11717821  ...        NaN      NaN       NaN
# 11385  10196667  11717821  11140901  ...        NaN      NaN       NaN
# 11386  10121545   9520329   8433918  ...        NaN      NaN       NaN
# 11387   5017824   2368605   7501267  ...        NaN      NaN       NaN
# 11388   2766726   2766726   2766726  ...        NaN      NaN       NaN
# 11389   5338822   6281579   4048876  ...        NaN      NaN       NaN
# 11390  11140901   5595070   8946537  ...        NaN      NaN       NaN
# 11391  10622510  10622510  10622510  ...        NaN      NaN       NaN
# 11392   2643626   2511046   5477019  ...        NaN      NaN       NaN
# 11393  10811396  11922313  12379158  ...        NaN      NaN       NaN
# 11394   9845944   1620994  12418021  ...        NaN      NaN       NaN
# 11395  11140901   5595070  12269200  ...        NaN      NaN       NaN
# 11396  12569394  11717821  11140901  ...        NaN      NaN       NaN
# 11397   5619538   5619538   5619538  ...        NaN      NaN       NaN
#
#              59  60  61  62  63  64  65
# 0           NaN NaN NaN NaN NaN NaN NaN
# 1           NaN NaN NaN NaN NaN NaN NaN
# 2           NaN NaN NaN NaN NaN NaN NaN
# 3           NaN NaN NaN NaN NaN NaN NaN
# 4           NaN NaN NaN NaN NaN NaN NaN
# 5           NaN NaN NaN NaN NaN NaN NaN
# 6           NaN NaN NaN NaN NaN NaN NaN
# 7           NaN NaN NaN NaN NaN NaN NaN
# 8           NaN NaN NaN NaN NaN NaN NaN
# 9           NaN NaN NaN NaN NaN NaN NaN
# 10          NaN NaN NaN NaN NaN NaN NaN
# 11          NaN NaN NaN NaN NaN NaN NaN
# 12          NaN NaN NaN NaN NaN NaN NaN
# 13          NaN NaN NaN NaN NaN NaN NaN
# 14          NaN NaN NaN NaN NaN NaN NaN
# 15          NaN NaN NaN NaN NaN NaN NaN
# 16          NaN NaN NaN NaN NaN NaN NaN
# 17          NaN NaN NaN NaN NaN NaN NaN
# 18          NaN NaN NaN NaN NaN NaN NaN
# 19          NaN NaN NaN NaN NaN NaN NaN
# 20          NaN NaN NaN NaN NaN NaN NaN
# 21          NaN NaN NaN NaN NaN NaN NaN
# 22          NaN NaN NaN NaN NaN NaN NaN
# 23          NaN NaN NaN NaN NaN NaN NaN
# 24          NaN NaN NaN NaN NaN NaN NaN
# 25          NaN NaN NaN NaN NaN NaN NaN
# 26          NaN NaN NaN NaN NaN NaN NaN
# 27          NaN NaN NaN NaN NaN NaN NaN
# 28          NaN NaN NaN NaN NaN NaN NaN
# 29          NaN NaN NaN NaN NaN NaN NaN
# ...         ...  ..  ..  ..  ..  ..  ..
# 11368       NaN NaN NaN NaN NaN NaN NaN
# 11369       NaN NaN NaN NaN NaN NaN NaN
# 11370       NaN NaN NaN NaN NaN NaN NaN
# 11371       NaN NaN NaN NaN NaN NaN NaN
# 11372       NaN NaN NaN NaN NaN NaN NaN
# 11373       NaN NaN NaN NaN NaN NaN NaN
# 11374       NaN NaN NaN NaN NaN NaN NaN
# 11375       NaN NaN NaN NaN NaN NaN NaN
# 11376       NaN NaN NaN NaN NaN NaN NaN
# 11377       NaN NaN NaN NaN NaN NaN NaN
# 11378       NaN NaN NaN NaN NaN NaN NaN
# 11379       NaN NaN NaN NaN NaN NaN NaN
# 11380       NaN NaN NaN NaN NaN NaN NaN
# 11381       NaN NaN NaN NaN NaN NaN NaN
# 11382  828172.0 NaN NaN NaN NaN NaN NaN
# 11383       NaN NaN NaN NaN NaN NaN NaN
# 11384       NaN NaN NaN NaN NaN NaN NaN
# 11385       NaN NaN NaN NaN NaN NaN NaN
# 11386       NaN NaN NaN NaN NaN NaN NaN
# 11387       NaN NaN NaN NaN NaN NaN NaN
# 11388       NaN NaN NaN NaN NaN NaN NaN
# 11389       NaN NaN NaN NaN NaN NaN NaN
# 11390       NaN NaN NaN NaN NaN NaN NaN
# 11391       NaN NaN NaN NaN NaN NaN NaN
# 11392       NaN NaN NaN NaN NaN NaN NaN
# 11393       NaN NaN NaN NaN NaN NaN NaN
# 11394       NaN NaN NaN NaN NaN NaN NaN
# 11395       NaN NaN NaN NaN NaN NaN NaN
# 11396       NaN NaN NaN NaN NaN NaN NaN
# 11397       NaN NaN NaN NaN NaN NaN NaN
#
# [11398 rows x 66 columns]

# %%
result.iloc[:,:31].fillna('11680535').astype(int).to_csv('../data/f_5.csv',index=None,header=False)

# %%
usercf_pred = UserBasedCF()
usercf_pred.generate_dataset(pd.concat([train_yy[['buyer_admin_id','item_id']],test_df[['buyer_admin_id','item_id']]]),
                             test_df[['buyer_admin_id','item_id']].drop_duplicates(subset=['buyer_admin_id'], keep='first'))
usercf_pred.calc_user_sim()

import pickle
output = open('./usercf_pred_round2.pkl', 'wb')
pickle.dump(usercf_pred, output)
output.close()
# Out:
# 相似用户数目为  10
# 推荐Item数目为  30
# 预测！

# %%
import sys
import random
import math
import os
from operator import itemgetter

from collections import defaultdict

random.seed(0)

class UserBasedCF(object):
    ''' TopN recommendation - User Based Collaborative Filtering '''

    # 构造函数，用来初始化
    def __init__(self):
        # 定义 训练集 测试集 为字典类型
        self.trainset = {}
        self.testset = {}
        # 训练集用的相似用户数
        self.n_sim_user = 10
        # 推荐Item数量
        self.n_rec_item = 30

        self.user_sim_mat = {}  # 相似用户
        self.item_popular = {}
        self.item_count = 0
        # sys.stderr 是用来重定向标准错误信息的
        print ('相似用户数目为  %d' % self.n_sim_user, file=sys.stderr)
        print ('推荐Item数目为  %d' % self.n_rec_item, file=sys.stderr)

    # 划分训练集和测试集 pivot用来定义训练集和测试集的比例
    def generate_dataset(self, train, test=None, pivot=1):
        ''' load rating data and split it to training set and test set '''
        trainset_len = 0
        testset_len = 0
        if test is None:# 随机分配验证机实验 
            print('算法尝试！')
            for line in train.iterrows():
                user, item, rating = line[1][0],line[1][1],1
                
                if random.random() < pivot: # split the data by pivot
                    self.trainset.setdefault(user, {})
                    self.trainset[user][item] = int(rating)
                    trainset_len += 1
                else:
                    self.testset.setdefault(user, {})
                    self.testset[user][item] = int(rating)
                    testset_len += 1
        else:
            print('预测！')
            for line in train.iterrows():
                user, item, rating = line[1][0],line[1][1],1
                self.trainset.setdefault(user, {})
                self.trainset[user][item] = int(rating)
                trainset_len += 1
            del user,item,rating
            for line in test.iterrows():
                user, item, rating = line[1][0],line[1][1],1
                self.testset.setdefault(user, {})
                self.testset[user][item] = int(rating)
                testset_len += 1
        print ('split training set and test set succ')
        print ('train set = %s' % trainset_len)
        print ('test set = %s' % testset_len)
        
    # 建立物品-用户 倒排表
    def calc_user_sim(self):
        ''' calculate user similarity matrix '''
        # build inverse table for item-users
        # key=itemID, value=list of userIDs who have seen this item
        print ('构建物品-用户倒排表中，请等待......')
        item2users = dict()

        for user, items in self.trainset.items():
            for item in items:
                # inverse table for item-users
                if item not in item2users:
                    # 根据商品id 构造set() 函数创建一个无序不重复元素集
                    item2users[item] = set()
                item2users[item].add(user)
                # 记录流行度
                if item not in self.item_popular:
                    self.item_popular[item] = 0
                self.item_popular[item] += 1
        print ('构建物品-用户倒排表成功', file=sys.stderr)

        # save the total item number, which will be used in evaluation
        self.item_count = len(item2users)
        print ('总共被操作过的物品数目为  %d' % self.item_count, file=sys.stderr)

        # count co-rated items between users
        usersim_mat = self.user_sim_mat

        print ('building user co-rated items matrix...', file=sys.stderr)
        # 令系数矩阵 C[u][v]表示N(u)∩N（v) ，假如用户u和用户v同时属于K个物品对应的用户列表，就有C[u][v]=K
        for item, users in item2users.items():
            for u in users:
                usersim_mat.setdefault(u, defaultdict(int))
                for v in users:
                    if u == v:
                        continue
                    usersim_mat[u][v] += 1
        print ('build user co-rated items matrix succ', file=sys.stderr)

        # calculate similarity matrix
        print ('calculating user similarity matrix...', file=sys.stderr)
        simfactor_count = 0
        PRINT_STEP = 2000000
        # 循环遍历usersim_mat 根据余弦相似度公式计算出用户兴趣相似度
        for u, related_users in usersim_mat.items():
            for v, count in related_users.items():
                # 以下是公式计算过程
                usersim_mat[u][v] = count / math.sqrt(
                    len(self.trainset[u]) * len(self.trainset[v]))
                #计数 并没有什么卵用
                simfactor_count += 1
                if simfactor_count % PRINT_STEP == 0:
                    print ('calculating user similarity factor(%d)' %
                           simfactor_count, file=sys.stderr)

        print ('calculate user similarity matrix(similarity factor) succ',
               file=sys.stderr)
        print ('Total similarity factor number = %d' %
               simfactor_count, file=sys.stderr)
        
    # 根据用户给予推荐结果
    def recommend(self, user, predict=False):
        '''定义给定K个相似用户和推荐N个商品'''
        K = self.n_sim_user   # 相似用户数
        N = self.n_rec_item   # 推荐商品数
        
        rank = dict() # 定义一个字典来存储为用户推荐的商品
        
        watched_items = self.trainset[user]
        # sorted() 函数对所有可迭代的对象进行排序操作。 key 指定比较的对象 ，reverse=True 降序
        for similar_user, similarity_factor in sorted(self.user_sim_mat[user].items(),
                                                      key=itemgetter(1), reverse=True)[0:K]:
#             print(similar_user)
#             print(similarity_factor)
            for item in self.trainset[similar_user]:
                rank.setdefault(item, 0)
                rank[item] += similarity_factor
        # return the N best items
        return sorted(rank.items(), key=itemgetter(1), reverse=True)[0:N]
    
    def predict(self):
        print('Predict start...')

        N = self.n_rec_item
        #  varables for precision and recall
        hit = 0
        rec_count = 0
        test_count = 0
        # varables for coverage
        all_rec_items = set()
        # varables for popularity
        popular_sum = 0
        predict_result=[]
        for i, user in enumerate(self.testset):
            if i % 500 == 0:
                print ('recommended for %d users' % i)
            rec_items = self.recommend(user,predict=True)
            predict_result.append((user,rec_items))
        print('Predict end...')
        return predict_result
    
    # 计算 准确略，召回率，覆盖率，流行度
    def evaluate(self):
        ''' print evaluation result: precision, recall, coverage and popularity '''
        print ('Evaluation start...', file=sys.stderr)

        N = self.n_rec_item
        #  varables for precision and recall
        #记录推荐正确的item数
        hit = 0
        #记录推荐item的总数
        rec_count = 0
        #记录测试数据中总数
        test_count = 0
        # varables for coverage
        all_rec_items = set()
        # varables for popularity
        popular_sum = 0

        for i, user in enumerate(self.trainset):
            if i % 500 == 0:
                print ('recommended for %d users' % i, file=sys.stderr)
            test_items = self.testset.get(user, {})
            rec_items = self.recommend(user,predict=False)
            for item, _ in rec_items:
                if item in test_items:
                    hit += 1
                all_rec_items.add(item)
                popular_sum += math.log(1 + self.item_popular[item])
            rec_count += N
            test_count += len(test_items)
        # 计算准确度
        precision = hit / (1.0 * rec_count)
        # 计算召回率
        recall = hit / (1.0 * test_count)
        # 计算覆盖率
        coverage = len(all_rec_items) / (1.0 * self.item_count)
        #计算流行度
        popularity = popular_sum / (1.0 * rec_count)

        print ('precision=%.4f\trecall=%.4f\tcoverage=%.4f\tpopularity=%.4f' %
               (precision, recall, coverage, popularity), file=sys.stderr)

# %%
item_based = ItemBasedCF()

item_based.generate_dataset(train_yy[['buyer_admin_id','item_id']][0:1000],train_yy[['buyer_admin_id','item_id']][5:8])

item_based.calc_item_sim()
# Out:
# Similar item number = 30
# Recommended item number = 30
# 预测！
# split training set and test set succ
# train set = 1000
# test set = 3
# counting items number and popularity...
# count items number and popularity succ
# total item number = 475
# building co-rated users matrix...
# build co-rated users matrix succ
# calculating item similarity matrix...
# calculate item similarity matrix(similarity factor) succ
# Total similarity factor number = 272

# %%
item_based.item_sim_mat
# Out:
# {3: defaultdict(int, {}),
#  6: defaultdict(int,
#              {478: 0.2886751345948129,
#               3354: 0.13423121104280486,
#               3831: 0.05184758473652126,
#               2937: 0.0445435403187374}),
#  478: defaultdict(int, {6: 0.2886751345948129}),
#  3354: defaultdict(int,
#              {6: 0.13423121104280486,
#               3831: 0.37581646079669545,
#               2937: 0.376685401750442,
#               455: 0.08219949365267865,
#               464: 0.11624763874381928,
#               466: 0.08219949365267865,
#               2922: 0.10397504898200728,
#               3293: 0.10067340828210365,
#               3912: 0.15499685165842572,
#               3905: 0.1643989873053573,
#               4007: 0.1643989873053573,
#               3961: 0.11624763874381928}),
#  3831: defaultdict(int,
#              {6: 0.05184758473652126,
#               3354: 0.37581646079669545,
#               428: 0.1270001270001905,
#               452: 0.1270001270001905,
#               455: 0.1270001270001905,
#               4321: 0.1796053020267749,
#               2922: 0.08032193289024989,
#               2937: 0.33256439728421594,
#               3912: 0.17960530202677488,
#               3351: 0.1796053020267749,
#               3827: 0.1796053020267749,
#               3828: 0.1796053020267749,
#               3293: 0.05184758473652126}),
#  2937: defaultdict(int,
#              {6: 0.0445435403187374,
#               3354: 0.376685401750442,
#               428: 0.1091089451179962,
#               452: 0.1091089451179962,
#               444: 0.1543033499620919,
#               2922: 0.13801311186847084,
#               464: 0.1543033499620919,
#               466: 0.1091089451179962,
#               3831: 0.33256439728421594,
#               3912: 0.1543033499620919,
#               3293: 0.0445435403187374,
#               3351: 0.1543033499620919,
#               3827: 0.1543033499620919,
#               3828: 0.1543033499620919}),
#  83: defaultdict(int, {}),
#  85: defaultdict(int, {86: 1.0, 87: 1.0, 91: 1.0, 2091: 1.0}),
#  86: defaultdict(int, {85: 1.0, 87: 1.0, 91: 1.0, 2091: 1.0}),
#  87: defaultdict(int, {85: 1.0, 86: 1.0, 91: 1.0, 2091: 1.0}),
#  91: defaultdict(int, {85: 1.0, 86: 1.0, 87: 1.0, 2091: 1.0}),
#  2091: defaultdict(int, {85: 1.0, 86: 1.0, 87: 1.0, 91: 1.0}),
#  99: defaultdict(int, {1013: 1.0}),
#  1013: defaultdict(int, {99: 1.0}),
#  108: defaultdict(int, {}),
#  109: defaultdict(int, {}),
#  110: defaultdict(int, {}),
#  127: defaultdict(int, {}),
#  129: defaultdict(int, {}),
#  130: defaultdict(int, {}),
#  132: defaultdict(int, {}),
#  134: defaultdict(int, {}),
#  141: defaultdict(int, {}),
#  142: defaultdict(int, {}),
#  145: defaultdict(int, {}),
#  146: defaultdict(int, {157: 1.0}),
#  157: defaultdict(int, {146: 1.0}),
#  147: defaultdict(int,
#              {576: 1.0, 1633: 1.0, 1871: 1.0, 4060: 0.7071067811865475}),
#  576: defaultdict(int,
#              {147: 1.0, 1633: 1.0, 1871: 1.0, 4060: 0.7071067811865475}),
#  1633: defaultdict(int,
#              {147: 1.0, 576: 1.0, 1871: 1.0, 4060: 0.7071067811865475}),
#  1871: defaultdict(int,
#              {147: 1.0, 576: 1.0, 1633: 1.0, 4060: 0.7071067811865475}),
#  4060: defaultdict(int,
#              {147: 0.7071067811865475,
#               576: 0.7071067811865475,
#               1633: 0.7071067811865475,
#               1871: 0.7071067811865475}),
#  152: defaultdict(int, {1245: 1.0}),
#  1245: defaultdict(int, {152: 1.0}),
#  153: defaultdict(int, {}),
#  154: defaultdict(int, {}),
#  160: defaultdict(int, {}),
#  164: defaultdict(int, {2070: 0.7071067811865475}),
#  2070: defaultdict(int, {164: 0.7071067811865475}),
#  165: defaultdict(int, {4983: 1.0}),
#  4983: defaultdict(int, {165: 1.0}),
#  172: defaultdict(int, {}),
#  174: defaultdict(int, {}),
#  182: defaultdict(int, {}),
#  188: defaultdict(int, {}),
#  189: defaultdict(int,
#              {4788: 0.7071067811865475,
#               1136: 0.7071067811865475,
#               1653: 0.4082482904638631}),
#  4788: defaultdict(int, {189: 0.7071067811865475}),
#  1136: defaultdict(int, {189: 0.7071067811865475, 1653: 0.5773502691896258}),
#  1653: defaultdict(int, {189: 0.4082482904638631, 1136: 0.5773502691896258}),
#  200: defaultdict(int, {}),
#  205: defaultdict(int, {}),
#  208: defaultdict(int, {}),
#  233: defaultdict(int, {}),
#  234: defaultdict(int, {}),
#  259: defaultdict(int, {}),
#  262: defaultdict(int, {2020: 0.7071067811865475}),
#  2020: defaultdict(int, {262: 0.7071067811865475}),
#  267: defaultdict(int, {}),
#  271: defaultdict(int, {407: 0.5}),
#  407: defaultdict(int, {271: 0.5}),
#  276: defaultdict(int, {312: 0.31622776601683794, 410: 0.31622776601683794}),
#  312: defaultdict(int, {276: 0.31622776601683794, 410: 1.0}),
#  410: defaultdict(int, {276: 0.31622776601683794, 312: 1.0}),
#  313: defaultdict(int, {}),
#  415: defaultdict(int, {}),
#  428: defaultdict(int,
#              {452: 1.0,
#               2937: 0.1091089451179962,
#               455: 0.5,
#               3831: 0.1270001270001905,
#               4321: 0.7071067811865475}),
#  452: defaultdict(int,
#              {428: 1.0,
#               2937: 0.1091089451179962,
#               455: 0.5,
#               3831: 0.1270001270001905,
#               4321: 0.7071067811865475}),
#  455: defaultdict(int,
#              {428: 0.5,
#               452: 0.5,
#               3831: 0.1270001270001905,
#               4321: 0.7071067811865475,
#               3354: 0.08219949365267865}),
#  4321: defaultdict(int,
#              {428: 0.7071067811865475,
#               452: 0.7071067811865475,
#               455: 0.7071067811865475,
#               3831: 0.1796053020267749}),
#  444: defaultdict(int, {2922: 0.4472135954999579, 2937: 0.1543033499620919}),
#  2922: defaultdict(int,
#              {444: 0.4472135954999579,
#               2937: 0.13801311186847084,
#               497: 0.4472135954999579,
#               3293: 0.2581988897471611,
#               3912: 0.29814239699997197,
#               3354: 0.10397504898200728,
#               3831: 0.08032193289024989}),
#  458: defaultdict(int, {484: 0.7071067811865475}),
#  484: defaultdict(int, {458: 0.7071067811865475}),
#  464: defaultdict(int,
#              {466: 0.7071067811865475,
#               2937: 0.1543033499620919,
#               3354: 0.11624763874381928}),
#  466: defaultdict(int,
#              {464: 0.7071067811865475,
#               2937: 0.1091089451179962,
#               3354: 0.08219949365267865}),
#  476: defaultdict(int, {}),
#  485: defaultdict(int, {}),
#  486: defaultdict(int, {}),
#  488: defaultdict(int, {489: 1.0}),
#  489: defaultdict(int, {488: 1.0}),
#  492: defaultdict(int, {}),
#  493: defaultdict(int, {541: 1.0}),
#  541: defaultdict(int, {493: 1.0}),
#  495: defaultdict(int, {}),
#  496: defaultdict(int, {}),
#  497: defaultdict(int,
#              {2922: 0.4472135954999579,
#               3293: 0.2886751345948129,
#               3912: 0.3333333333333333}),
#  3293: defaultdict(int,
#              {497: 0.2886751345948129,
#               2922: 0.2581988897471611,
#               3912: 0.4811252243246881,
#               2937: 0.0445435403187374,
#               3354: 0.10067340828210365,
#               3831: 0.05184758473652126,
#               3905: 0.20412414523193154}),
#  3912: defaultdict(int,
#              {497: 0.3333333333333333,
#               2922: 0.29814239699997197,
#               3293: 0.4811252243246881,
#               2937: 0.1543033499620919,
#               3831: 0.17960530202677488,
#               3354: 0.15499685165842572,
#               3351: 0.3333333333333333,
#               3827: 0.3333333333333333,
#               3828: 0.3333333333333333,
#               3905: 0.23570226039551587,
#               4007: 0.23570226039551587}),
#  499: defaultdict(int, {}),
#  503: defaultdict(int, {}),
#  513: defaultdict(int, {}),
#  517: defaultdict(int, {}),
#  529: defaultdict(int, {}),
#  533: defaultdict(int, {}),
#  539: defaultdict(int, {}),
#  573: defaultdict(int, {5350: 1.0}),
#  5350: defaultdict(int, {573: 1.0}),
#  580: defaultdict(int, {}),
#  586: defaultdict(int, {}),
#  588: defaultdict(int, {}),
#  589: defaultdict(int, {}),
#  611: defaultdict(int, {}),
#  618: defaultdict(int, {}),
#  629: defaultdict(int, {}),
#  632: defaultdict(int, {973: 1.0}),
#  973: defaultdict(int, {632: 1.0}),
#  636: defaultdict(int, {677: 0.1889822365046136}),
#  677: defaultdict(int,
#              {636: 0.1889822365046136,
#               676: 0.2672612419124244,
#               909: 0.1336306209562122}),
#  654: defaultdict(int, {}),
#  659: defaultdict(int, {}),
#  660: defaultdict(int, {}),
#  674: defaultdict(int, {}),
#  676: defaultdict(int, {677: 0.2672612419124244, 909: 0.5}),
#  909: defaultdict(int, {676: 0.5, 677: 0.1336306209562122}),
#  858: defaultdict(int, {}),
#  859: defaultdict(int, {}),
#  861: defaultdict(int, {4012: 1.0}),
#  4012: defaultdict(int, {861: 1.0}),
#  862: defaultdict(int, {}),
#  864: defaultdict(int, {}),
#  870: defaultdict(int, {}),
#  873: defaultdict(int, {}),
#  899: defaultdict(int, {4183: 1.0, 4190: 1.0}),
#  4183: defaultdict(int, {899: 1.0, 4190: 1.0}),
#  4190: defaultdict(int, {899: 1.0, 4183: 1.0}),
#  902: defaultdict(int, {}),
#  907: defaultdict(int, {1393: 1.0}),
#  1393: defaultdict(int, {907: 1.0}),
#  958: defaultdict(int, {}),
#  964: defaultdict(int, {}),
#  967: defaultdict(int, {}),
#  969: defaultdict(int, {}),
#  986: defaultdict(int, {}),
#  993: defaultdict(int, {}),
#  997: defaultdict(int, {}),
#  998: defaultdict(int, {1391: 0.7071067811865475}),
#  1391: defaultdict(int, {998: 0.7071067811865475}),
#  1006: defaultdict(int, {}),
#  1018: defaultdict(int, {}),
#  1032: defaultdict(int, {}),
#  1038: defaultdict(int, {}),
#  1065: defaultdict(int, {}),
#  1069: defaultdict(int, {}),
#  1081: defaultdict(int, {}),
#  1139: defaultdict(int, {}),
#  1140: defaultdict(int, {}),
#  1145: defaultdict(int, {}),
#  1146: defaultdict(int, {}),
#  1151: defaultdict(int, {}),
#  1152: defaultdict(int, {}),
#  1153: defaultdict(int, {}),
#  1164: defaultdict(int, {}),
#  1165: defaultdict(int, {}),
#  1169: defaultdict(int, {}),
#  1179: defaultdict(int, {}),
#  1181: defaultdict(int, {}),
#  1184: defaultdict(int, {}),
#  1194: defaultdict(int, {1197: 1.0}),
#  1197: defaultdict(int, {1194: 1.0}),
#  1198: defaultdict(int, {}),
#  1199: defaultdict(int, {}),
#  1205: defaultdict(int, {}),
#  1207: defaultdict(int, {}),
#  1211: defaultdict(int, {}),
#  1218: defaultdict(int, {1553: 1.0, 1637: 1.0, 4506: 1.0}),
#  1553: defaultdict(int, {1218: 1.0, 1637: 1.0, 4506: 1.0}),
#  1637: defaultdict(int, {1218: 1.0, 1553: 1.0, 4506: 1.0}),
#  4506: defaultdict(int, {1218: 1.0, 1553: 1.0, 1637: 1.0}),
#  1258: defaultdict(int, {}),
#  1267: defaultdict(int, {1272: 0.7071067811865475}),
#  1272: defaultdict(int, {1267: 0.7071067811865475}),
#  1274: defaultdict(int, {}),
#  1275: defaultdict(int, {}),
#  1305: defaultdict(int, {}),
#  1307: defaultdict(int, {}),
#  1309: defaultdict(int, {}),
#  1314: defaultdict(int, {}),
#  1323: defaultdict(int, {}),
#  1329: defaultdict(int, {}),
#  1334: defaultdict(int, {}),
#  1343: defaultdict(int, {}),
#  1344: defaultdict(int, {}),
#  1348: defaultdict(int, {}),
#  1351: defaultdict(int, {}),
#  1370: defaultdict(int, {4907: 0.35355339059327373}),
#  4907: defaultdict(int,
#              {1370: 0.35355339059327373, 4745: 0.14433756729740646}),
#  1373: defaultdict(int, {}),
#  1382: defaultdict(int, {}),
#  1386: defaultdict(int, {}),
#  1389: defaultdict(int, {}),
#  1396: defaultdict(int, {}),
#  1401: defaultdict(int, {}),
#  1427: defaultdict(int, {}),
#  1429: defaultdict(int, {}),
#  1432: defaultdict(int, {}),
#  1433: defaultdict(int, {}),
#  1439: defaultdict(int, {}),
#  1442: defaultdict(int, {}),
#  1454: defaultdict(int, {}),
#  1455: defaultdict(int, {}),
#  1465: defaultdict(int, {}),
#  1470: defaultdict(int, {}),
#  1519: defaultdict(int, {}),
#  1522: defaultdict(int, {}),
#  1532: defaultdict(int, {}),
#  1534: defaultdict(int, {}),
#  1537: defaultdict(int, {}),
#  1547: defaultdict(int, {}),
#  1549: defaultdict(int, {}),
#  1551: defaultdict(int, {1552: 1.0, 2102: 1.0, 2801: 1.0}),
#  1552: defaultdict(int, {1551: 1.0, 2102: 1.0, 2801: 1.0}),
#  2102: defaultdict(int, {1551: 1.0, 1552: 1.0, 2801: 1.0}),
#  2801: defaultdict(int, {1551: 1.0, 1552: 1.0, 2102: 1.0}),
#  1554: defaultdict(int, {}),
#  1562: defaultdict(int, {}),
#  1566: defaultdict(int, {}),
#  1571: defaultdict(int, {}),
#  1572: defaultdict(int, {}),
#  1573: defaultdict(int, {}),
#  1589: defaultdict(int, {}),
#  1603: defaultdict(int, {}),
#  1609: defaultdict(int, {}),
#  1612: defaultdict(int, {}),
#  1614: defaultdict(int, {}),
#  1618: defaultdict(int, {}),
#  1620: defaultdict(int, {}),
#  1623: defaultdict(int, {}),
#  1675: defaultdict(int, {}),
#  1679: defaultdict(int, {}),
#  1683: defaultdict(int, {}),
#  1685: defaultdict(int, {4509: 1.0}),
#  4509: defaultdict(int, {1685: 1.0}),
#  1689: defaultdict(int, {}),
#  1701: defaultdict(int, {}),
#  1702: defaultdict(int, {}),
#  1704: defaultdict(int, {}),
#  1705: defaultdict(int, {}),
#  1714: defaultdict(int, {}),
#  1726: defaultdict(int, {}),
#  1728: defaultdict(int, {}),
#  1732: defaultdict(int, {}),
#  1736: defaultdict(int, {1749: 1.0}),
#  1749: defaultdict(int, {1736: 1.0}),
#  1737: defaultdict(int, {}),
#  1738: defaultdict(int, {}),
#  1740: defaultdict(int, {}),
#  1747: defaultdict(int, {}),
#  1760: defaultdict(int, {}),
#  1793: defaultdict(int, {}),
#  1796: defaultdict(int, {}),
#  1799: defaultdict(int, {}),
#  1815: defaultdict(int, {}),
#  1822: defaultdict(int, {}),
#  1824: defaultdict(int, {}),
#  1828: defaultdict(int, {}),
#  1834: defaultdict(int, {}),
#  1835: defaultdict(int, {}),
#  1840: defaultdict(int, {}),
#  1874: defaultdict(int, {}),
#  1875: defaultdict(int, {}),
#  1878: defaultdict(int, {}),
#  1882: defaultdict(int, {}),
#  1888: defaultdict(int, {}),
#  1892: defaultdict(int, {}),
#  1893: defaultdict(int, {}),
#  1908: defaultdict(int, {}),
#  1915: defaultdict(int, {}),
#  1917: defaultdict(int, {}),
#  1918: defaultdict(int, {}),
#  1932: defaultdict(int, {}),
#  1934: defaultdict(int, {}),
#  1935: defaultdict(int, {}),
#  1966: defaultdict(int, {}),
#  1980: defaultdict(int, {}),
#  2004: defaultdict(int, {2072: 1.0, 2075: 1.0}),
#  2072: defaultdict(int, {2004: 1.0, 2075: 1.0}),
#  2075: defaultdict(int, {2004: 1.0, 2072: 1.0}),
#  2006: defaultdict(int, {}),
#  2033: defaultdict(int, {}),
#  2034: defaultdict(int, {}),
#  2038: defaultdict(int, {}),
#  2040: defaultdict(int, {}),
#  2044: defaultdict(int, {}),
#  2048: defaultdict(int, {}),
#  2058: defaultdict(int, {}),
#  2061: defaultdict(int, {}),
#  2069: defaultdict(int, {2077: 1.0}),
#  2077: defaultdict(int, {2069: 1.0}),
#  2083: defaultdict(int, {}),
#  2085: defaultdict(int, {}),
#  2094: defaultdict(int, {}),
#  2096: defaultdict(int, {}),
#  2097: defaultdict(int, {}),
#  2107: defaultdict(int, {}),
#  2109: defaultdict(int, {}),
#  2114: defaultdict(int, {}),
#  2122: defaultdict(int, {}),
#  2124: defaultdict(int, {}),
#  2125: defaultdict(int, {2126: 1.0}),
#  2126: defaultdict(int, {2125: 1.0}),
#  2139: defaultdict(int, {}),
#  2140: defaultdict(int, {}),
#  2161: defaultdict(int, {}),
#  2166: defaultdict(int, {}),
#  2176: defaultdict(int, {}),
#  2179: defaultdict(int, {}),
#  2196: defaultdict(int, {}),
#  2203: defaultdict(int, {}),
#  2218: defaultdict(int, {}),
#  2225: defaultdict(int, {}),
#  2226: defaultdict(int, {}),
#  2228: defaultdict(int, {}),
#  2239: defaultdict(int, {}),
#  2241: defaultdict(int, {}),
#  2244: defaultdict(int, {}),
#  2246: defaultdict(int, {}),
#  2248: defaultdict(int, {2806: 0.05923488777590923}),
#  2806: defaultdict(int, {2248: 0.05923488777590923}),
#  2736: defaultdict(int, {}),
#  2739: defaultdict(int, {}),
#  2786: defaultdict(int, {}),
#  2787: defaultdict(int, {}),
#  2798: defaultdict(int, {}),
#  2846: defaultdict(int, {}),
#  2850: defaultdict(int, {}),
#  2861: defaultdict(int, {}),
#  2865: defaultdict(int, {}),
#  2869: defaultdict(int, {4366: 0.7071067811865475}),
#  4366: defaultdict(int, {2869: 0.7071067811865475}),
#  2871: defaultdict(int, {}),
#  2912: defaultdict(int, {}),
#  2918: defaultdict(int, {}),
#  2920: defaultdict(int, {}),
#  2935: defaultdict(int, {}),
#  3351: defaultdict(int,
#              {2937: 0.1543033499620919,
#               3827: 1.0,
#               3828: 1.0,
#               3831: 0.1796053020267749,
#               3912: 0.3333333333333333}),
#  3827: defaultdict(int,
#              {2937: 0.1543033499620919,
#               3351: 1.0,
#               3828: 1.0,
#               3831: 0.1796053020267749,
#               3912: 0.3333333333333333}),
#  3828: defaultdict(int,
#              {2937: 0.1543033499620919,
#               3351: 1.0,
#               3827: 1.0,
#               3831: 0.1796053020267749,
#               3912: 0.3333333333333333}),
#  3905: defaultdict(int,
#              {3293: 0.20412414523193154,
#               3354: 0.1643989873053573,
#               3912: 0.23570226039551587,
#               4007: 0.5}),
#  4007: defaultdict(int,
#              {3354: 0.1643989873053573, 3905: 0.5, 3912: 0.23570226039551587}),
#  3961: defaultdict(int, {3354: 0.11624763874381928}),
#  4013: defaultdict(int, {}),
#  4014: defaultdict(int, {}),
#  4021: defaultdict(int, {}),
#  4035: defaultdict(int, {}),
#  4037: defaultdict(int, {}),
#  4043: defaultdict(int, {}),
#  4049: defaultdict(int, {}),
#  4076: defaultdict(int, {}),
#  4078: defaultdict(int, {}),
#  4085: defaultdict(int, {}),
#  4092: defaultdict(int, {}),
#  4106: defaultdict(int, {}),
#  4109: defaultdict(int, {}),
#  4110: defaultdict(int, {}),
#  4113: defaultdict(int, {}),
#  4114: defaultdict(int, {}),
#  4118: defaultdict(int, {}),
#  4134: defaultdict(int, {}),
#  4138: defaultdict(int, {}),
#  4141: defaultdict(int, {}),
#  4153: defaultdict(int, {}),
#  4165: defaultdict(int, {}),
#  4168: defaultdict(int, {}),
#  4171: defaultdict(int, {}),
#  4177: defaultdict(int, {}),
#  4179: defaultdict(int, {}),
#  4180: defaultdict(int, {}),
#  4185: defaultdict(int, {}),
#  4187: defaultdict(int, {}),
#  4191: defaultdict(int, {}),
#  4192: defaultdict(int, {}),
#  4196: defaultdict(int, {}),
#  4220: defaultdict(int, {}),
#  4221: defaultdict(int, {4222: 1.0}),
#  4222: defaultdict(int, {4221: 1.0}),
#  4241: defaultdict(int, {}),
#  4248: defaultdict(int, {}),
#  4250: defaultdict(int, {}),
#  4252: defaultdict(int, {}),
#  4253: defaultdict(int, {}),
#  4255: defaultdict(int, {}),
#  4267: defaultdict(int, {}),
#  4268: defaultdict(int, {}),
#  4270: defaultdict(int, {}),
#  4272: defaultdict(int, {}),
#  4278: defaultdict(int, {}),
#  4279: defaultdict(int, {}),
#  4284: defaultdict(int, {}),
#  4303: defaultdict(int, {}),
#  4310: defaultdict(int, {}),
#  4320: defaultdict(int, {}),
#  4339: defaultdict(int, {}),
#  4340: defaultdict(int, {}),
#  4345: defaultdict(int, {}),
#  4386: defaultdict(int, {}),
#  4387: defaultdict(int, {}),
#  4394: defaultdict(int, {}),
#  4396: defaultdict(int, {}),
#  4421: defaultdict(int, {}),
#  4426: defaultdict(int, {}),
#  4431: defaultdict(int, {}),
#  4434: defaultdict(int, {}),
#  4443: defaultdict(int, {}),
#  4447: defaultdict(int, {}),
#  4448: defaultdict(int, {}),
#  4453: defaultdict(int, {}),
#  4457: defaultdict(int, {}),
#  4459: defaultdict(int, {}),
#  4474: defaultdict(int, {}),
#  4480: defaultdict(int, {}),
#  4488: defaultdict(int, {}),
#  4502: defaultdict(int, {}),
#  4524: defaultdict(int, {}),
#  4540: defaultdict(int, {}),
#  4543: defaultdict(int, {}),
#  4544: defaultdict(int, {}),
#  4545: defaultdict(int, {}),
#  4606: defaultdict(int, {}),
#  4609: defaultdict(int, {}),
#  4611: defaultdict(int, {}),
#  4614: defaultdict(int, {}),
#  4656: defaultdict(int, {}),
#  4739: defaultdict(int, {}),
#  4740: defaultdict(int, {}),
#  4744: defaultdict(int, {}),
#  4745: defaultdict(int, {4907: 0.14433756729740646}),
#  4765: defaultdict(int, {}),
#  4766: defaultdict(int, {}),
#  4767: defaultdict(int, {}),
#  4777: defaultdict(int, {}),
#  4781: defaultdict(int, {}),
#  4782: defaultdict(int, {}),
#  4783: defaultdict(int, {}),
#  4795: defaultdict(int, {}),
#  4824: defaultdict(int, {}),
#  4848: defaultdict(int, {}),
#  4891: defaultdict(int, {}),
#  4899: defaultdict(int, {}),
#  4924: defaultdict(int, {}),
#  4937: defaultdict(int, {}),
#  4941: defaultdict(int, {}),
#  4947: defaultdict(int, {}),
#  4951: defaultdict(int, {}),
#  4960: defaultdict(int, {}),
#  4967: defaultdict(int, {}),
#  4969: defaultdict(int, {}),
#  4981: defaultdict(int, {}),
#  5042: defaultdict(int, {}),
#  5044: defaultdict(int, {}),
#  5051: defaultdict(int, {}),
#  5055: defaultdict(int, {}),
#  5076: defaultdict(int, {}),
#  5082: defaultdict(int, {}),
#  5085: defaultdict(int, {}),
#  5096: defaultdict(int, {}),
#  5112: defaultdict(int, {}),
#  5113: defaultdict(int, {}),
#  5131: defaultdict(int, {}),
#  5136: defaultdict(int, {}),
#  5144: defaultdict(int, {}),
#  5161: defaultdict(int, {}),
#  5162: defaultdict(int, {}),
#  5167: defaultdict(int, {}),
#  5180: defaultdict(int, {}),
#  5188: defaultdict(int, {}),
#  5196: defaultdict(int, {}),
#  5197: defaultdict(int, {}),
#  5200: defaultdict(int, {}),
#  5266: defaultdict(int, {}),
#  5268: defaultdict(int, {}),
#  5320: defaultdict(int, {}),
#  5324: defaultdict(int, {}),
#  5326: defaultdict(int, {}),
#  5344: defaultdict(int, {}),
#  5356: defaultdict(int, {})}

# %%
item_based.predict()
# Out:
# Predict start...
# recommended for 0 users
# {6: 1}
# {6: 1}
# {6: 1}
# Predict end...
# [(1283638,
#   [(478, 0.2886751345948129),
#    (3354, 0.13423121104280486),
#    (3831, 0.05184758473652126),
#    (2937, 0.0445435403187374)]),
#  (1414217,
#   [(478, 0.2886751345948129),
#    (3354, 0.13423121104280486),
#    (3831, 0.05184758473652126),
#    (2937, 0.0445435403187374)]),
#  (1159993,
#   [(478, 0.2886751345948129),
#    (3354, 0.13423121104280486),
#    (3831, 0.05184758473652126),
#    (2937, 0.0445435403187374)])]

# %%
itemcf_pred = ItemBasedCF()
itemcf_pred.generate_dataset(pd.concat([train_yy[['buyer_admin_id','item_id']],test_df[['buyer_admin_id','item_id']]]),
                             test_df[['buyer_admin_id','item_id']].drop_duplicates(subset=['buyer_admin_id'], keep='first'))
# Out:
# Similar item number = 30
# Recommended item number = 30
# 预测！
# split training set and test set succ
# train set = 2399699
# test set = 11398
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-4c0ef89487ef> in <module>
#       2 itemcf_pred.generate_dataset(pd.concat([train_yy[['buyer_admin_id','item_id']],test_df[['buyer_admin_id','item_id']]]),
#       3                              test_df[['buyer_admin_id','item_id']].drop_duplicates(subset=['buyer_admin_id'], keep='first'))
# ----> 4 itemcf_pred.calc_user_sim()
#       5
#       6 result_1 = itemcf_pred.predict()
#
# AttributeError: 'ItemBasedCF' object has no attribute 'calc_user_sim'

# %%
itemcf_pred.calc_item_sim()

result_1 = itemcf_pred.predict()
# Out:
# counting items number and popularity...
# count items number and popularity succ
# total item number = 972388
# building co-rated users matrix...
# build co-rated users matrix succ
# calculating item similarity matrix...
# calculating item similarity factor(2000000)
# calculating item similarity factor(4000000)
# calculating item similarity factor(6000000)
# calculating item similarity factor(8000000)
# calculating item similarity factor(10000000)
# calculating item similarity factor(12000000)
# calculating item similarity factor(14000000)
# calculating item similarity factor(16000000)
# calculating item similarity factor(18000000)
# calculating item similarity factor(20000000)
# calculating item similarity factor(22000000)
# calculating item similarity factor(24000000)
# calculating item similarity factor(26000000)
# calculating item similarity factor(28000000)
# calculating item similarity factor(30000000)
# calculating item similarity factor(32000000)
# calculating item similarity factor(34000000)
# calculating item similarity factor(36000000)
# calculating item similarity factor(38000000)
# calculating item similarity factor(40000000)
# calculate item similarity matrix(similarity factor) succ
# Total similarity factor number = 41031882
# Predict start...
# recommended for 0 users
# {189045: 1}
# {10713670: 1}
# {10546322: 1}
# {5199603: 1}
# {9156316: 1}
# {3477402: 1}
# {4547408: 1}
# {10216832: 1}
# {1602839: 1}
# {7412985: 1}
# {8099239: 1}
# {7521360: 1}
# {1610811: 1}
# {9630517: 1}
# {6423473: 1}
# {3060461: 1}
# {1736194: 1}
# {7096576: 1}
# {10708776: 1}
# {8162610: 1}
# {12970162: 1}
# {6003821: 1}
# {4311422: 1}
# {1662323: 1}
# {7979097: 1}
# {2473997: 1}
# {1042858: 1}
# {10588441: 1}
# {10331045: 1}
# {9977620: 1}
# {9112610: 1}
# {4686925: 1}
# {1969175: 1}
# {3712335: 1}
# {9565780: 1}
# {7195147: 1}
# {7138621: 1}
# {5610461: 1}
# {10860929: 1}
# {4201716: 1}
# {10960272: 1}
# {2562134: 1}
# {6552666: 1}
# {9393503: 1}
# {302389: 1}
# {7019890: 1}
# {9054327: 1}
# {2210000: 1}
# {6686854: 1}
# {8703248: 1}
# {10166752: 1}
# {7918160: 1}
# {3412039: 1}
# {547365: 1}
# {11006215: 1}
# {508272: 1}
# {9143415: 1}
# {8603859: 1}
# {6063925: 1}
# {10668833: 1}
# {10668833: 1}
# {220336: 1}
# {3993974: 1}
# {8168575: 1}
# {10593821: 1}
# {1650608: 1}
# {4455863: 1}
# {9131016: 1}
# {2218090: 1}
# {1267251: 1}
# {9727155: 1}
# {4361419: 1}
# {9504434: 1}
# {7618545: 1}
# {10972611: 1}
# {11358996: 1}
# {571550: 1}
# {11401426: 1}
# {8054462: 1}
# {12982091: 1}
# {7896150: 1}
# {1494921: 1}
# {9353765: 1}
# {4185085: 1}
# {8588265: 1}
# {2973334: 1}
# {7493723: 1}
# {5456055: 1}
# {2972666: 1}
# {11029902: 1}
# {8209418: 1}
# {4978806: 1}
# {5792644: 1}
# {10647442: 1}
# {10301234: 1}
# {8154830: 1}
# {10145081: 1}
# {9711280: 1}
# {4898345: 1}
# {6951381: 1}
# {4427303: 1}
# {3687512: 1}
# {416489: 1}
# {4309032: 1}
# {4769108: 1}
# {9342841: 1}
# {11359672: 1}
# {2412828: 1}
# {9469258: 1}
# {11814625: 1}
# {8615297: 1}
# {2018667: 1}
# {6355887: 1}
# {1619499: 1}
# {6775271: 1}
# {764087: 1}
# {5248694: 1}
# {1286408: 1}
# {2971526: 1}
# {2729015: 1}
# {9323998: 1}
# {6554931: 1}
# {9441957: 1}
# {3379183: 1}
# {7940616: 1}
# {1875457: 1}
# {6263789: 1}
# {11399008: 1}
# {8998420: 1}
# {6216648: 1}
# {9526864: 1}
# {5071861: 1}
# {5010547: 1}
# {8472048: 1}
# {10724828: 1}
# {11459372: 1}
# {3508538: 1}
# {1280590: 1}
# {7961665: 1}
# {7476226: 1}
# {11936234: 1}
# {7864419: 1}
# {5050911: 1}
# {5591163: 1}
# {8558035: 1}
# {4600190: 1}
# {7284874: 1}
# {5410985: 1}
# {9376069: 1}
# {4966770: 1}
# {835488: 1}
# {1607694: 1}
# {8360786: 1}
# {10910956: 1}
# {3907078: 1}
# {7852568: 1}
# {8949004: 1}
# {1933438: 1}
# {2390988: 1}
# {6980621: 1}
# {4514099: 1}
# {10325495: 1}
# {10654822: 1}
# {526713: 1}
# {11313070: 1}
# {10129800: 1}
# {10721511: 1}
# {12036890: 1}
# {1003101: 1}
# {5233535: 1}
# {8886563: 1}
# {3784734: 1}
# {5068060: 1}
# {412910: 1}
# {2998694: 1}
# {6977536: 1}
# {6338169: 1}
# {3481454: 1}
# {4762559: 1}
# {2736606: 1}
# {4585418: 1}
# {2826600: 1}
# {6382589: 1}
# {10198768: 1}
# {3127043: 1}
# {5769471: 1}
# {5486360: 1}
# {10207774: 1}
# {7153449: 1}
# {5977608: 1}
# {1155126: 1}
# {9515294: 1}
# {3392728: 1}
# {12186473: 1}
# {2672245: 1}
# {4736727: 1}
# {9857066: 1}
# {7692612: 1}
# {2813433: 1}
# {12186473: 1}
# {7446525: 1}
# {10682826: 1}
# {7727608: 1}
# {3134336: 1}
# {5595070: 1}
# {12186473: 1}
# {3785720: 1}
# {2715030: 1}
# {4119123: 1}
# {7189087: 1}
# {6678580: 1}
# {8326110: 1}
# {8125178: 1}
# {12186473: 1}
# {6519193: 1}
# {2539588: 1}
# {3534445: 1}
# {10072371: 1}
# {7847626: 1}
# {10583050: 1}
# {12966333: 1}
# {10286277: 1}
# {9049448: 1}
# {1961924: 1}
# {5061926: 1}
# {2909313: 1}
# {8998484: 1}
# {4273546: 1}
# {8226258: 1}
# {471806: 1}
# {26974: 1}
# {10000188: 1}
# {218852: 1}
# {3414666: 1}
# {6143405: 1}
# {9629501: 1}
# {1109961: 1}
# {6030610: 1}
# {11253334: 1}
# {11170447: 1}
# {12186473: 1}
# {2300709: 1}
# {5747532: 1}
# {5241074: 1}
# {7189244: 1}
# {9430299: 1}
# {4661169: 1}
# {7136358: 1}
# {5701392: 1}
# {9041190: 1}
# {7899182: 1}
# {4468187: 1}
# {656627: 1}
# {8799728: 1}
# {4218093: 1}
# {12931323: 1}
# {12186473: 1}
# {10225163: 1}
# {4467298: 1}
# {1422506: 1}
# {7118512: 1}
# {11792725: 1}
# {7176647: 1}
# {11073975: 1}
# {9921843: 1}
# {5120724: 1}
# {7649128: 1}
# {10456446: 1}
# {9437174: 1}
# {10059058: 1}
# {3647542: 1}
# {2300636: 1}
# {10610692: 1}
# {7798969: 1}
# {4357865: 1}
# {10445195: 1}
# {11755930: 1}
# {5500389: 1}
# {3178046: 1}
# {11860228: 1}
# {9718838: 1}
# {2197340: 1}
# {3224374: 1}
# {1734971: 1}
# {4368659: 1}
# {5662250: 1}
# {8575763: 1}
# {4629458: 1}
# {8950245: 1}
# {6955663: 1}
# {4172678: 1}
# {4756917: 1}
# {10686908: 1}
# {1931078: 1}
# {1011164: 1}
# {2370200: 1}
# {11505458: 1}
# {10732841: 1}
# {699177: 1}
# {11176252: 1}
# {11368788: 1}
# {10000188: 1}
# {7401321: 1}
# {9104872: 1}
# {11163420: 1}
# {10398910: 1}
# {3730448: 1}
# {10647977: 1}
# {7574839: 1}
# {7939904: 1}
# {11534661: 1}
# {7368233: 1}
# {9425579: 1}
# {3766589: 1}
# {3469455: 1}
# {7943575: 1}
# {11459029: 1}
# {9269577: 1}
# {10067133: 1}
# {10312398: 1}
# {2264600: 1}
# {3924861: 1}
# {5328255: 1}
# {4228107: 1}
# {2200459: 1}
# {246500: 1}
# {9707904: 1}
# {12006430: 1}
# {11528049: 1}
# {743394: 1}
# {4192474: 1}
# {5967267: 1}
# {12880275: 1}
# {1064296: 1}
# {7278212: 1}
# {186722: 1}
# {6956320: 1}
# {5675184: 1}
# {8152129: 1}
# {5322947: 1}
# {11075861: 1}
# {1468551: 1}
# {884593: 1}
# {10233642: 1}
# {3853710: 1}
# {2643650: 1}
# {11745835: 1}
# {3431885: 1}
# {6931257: 1}
# {10758629: 1}
# {10124369: 1}
# {9297565: 1}
# {3570526: 1}
# {7572770: 1}
# {11168475: 1}
# {2189159: 1}
# {10063978: 1}
# {6152555: 1}
# {3319531: 1}
# {7393699: 1}
# {1241604: 1}
# {917058: 1}
# {5337592: 1}
# {11166804: 1}
# {7005923: 1}
# {5517410: 1}
# {7042000: 1}
# {6192455: 1}
# {10602650: 1}
# {8673145: 1}
# {9486742: 1}
# {6541336: 1}
# {2743858: 1}
# {4879804: 1}
# {7743103: 1}
# {8754875: 1}
# {7930133: 1}
# {6721215: 1}
# {8233501: 1}
# {9744873: 1}
# {7906944: 1}
# {9585742: 1}
# {5642233: 1}
# {3077691: 1}
# {10683818: 1}
# {393812: 1}
# {11558766: 1}
# {9079121: 1}
# {5810263: 1}
# {3010611: 1}
# {7692404: 1}
# {2436277: 1}
# {6710890: 1}
# {9515616: 1}
# {11040805: 1}
# {11112653: 1}
# {6198743: 1}
# {7977628: 1}
# {3064373: 1}
# {2350739: 1}
# {9834333: 1}
# {4130454: 1}
# {9092027: 1}
# {9505712: 1}
# {5510336: 1}
# {1747368: 1}
# {4547040: 1}
# {8635450: 1}
# {11175579: 1}
# {6864248: 1}
# {5461439: 1}
# {8281336: 1}
# {2764172: 1}
# {6232744: 1}
# {7654755: 1}
# {8865497: 1}
# {2159885: 1}
# {2379506: 1}
# {7712720: 1}
# {1819513: 1}
# {8544454: 1}
# {10426105: 1}
# {1731454: 1}
# {9644004: 1}
# {12977656: 1}
# {3385592: 1}
# {9618016: 1}
# {1146473: 1}
# {8039371: 1}
# {9382971: 1}
# {2230633: 1}
# {2002634: 1}
# {9917937: 1}
# {11963902: 1}
# {2949279: 1}
# {804690: 1}
# {1720753: 1}
# {443754: 1}
# {10121538: 1}
# {10597293: 1}
# {7867431: 1}
# {1979471: 1}
# {11382081: 1}
# {11053450: 1}
# {6964723: 1}
# {10172001: 1}
# {3096666: 1}
# {6908412: 1}
# {8466276: 1}
# {7230375: 1}
# {7180655: 1}
# {10217033: 1}
# {8314325: 1}
# {4982708: 1}
# {1464587: 1}
# {6488996: 1}
# {4210728: 1}
# {9711280: 1}
# {10650261: 1}
# {9733992: 1}
# {9123396: 1}
# {322140: 1}
# {8197559: 1}
# {9577084: 1}
# {9833768: 1}
# {8551162: 1}
# {5246399: 1}
# {5119663: 1}
# {92641: 1}
# {5846650: 1}
# {9149018: 1}
# {11597858: 1}
# {7888149: 1}
# {5638894: 1}
# {8443514: 1}
# {5723433: 1}
# {6454891: 1}
# {10991299: 1}
# {3266133: 1}
# {6079072: 1}
# {5242010: 1}
# {5093108: 1}
# {5197858: 1}
# {3951567: 1}
# {7994277: 1}
# {4425156: 1}
# {576722: 1}
# {5610327: 1}
# {9905716: 1}
# {9403359: 1}
# {6691576: 1}
# {10313945: 1}
# {8471761: 1}
# {1386194: 1}
# {9722048: 1}
# {11793562: 1}
# {7890470: 1}
# {9108722: 1}
# {1191567: 1}
# {9672864: 1}
# recommended for 500 users
# {9117413: 1}
# {7445847: 1}
# {9834712: 1}
# {9355210: 1}
# {10689085: 1}
# {11672236: 1}
# {4159853: 1}
# {4510673: 1}
# {5990105: 1}
# {9560649: 1}
# {3956367: 1}
# {2226763: 1}
# {6195515: 1}
# {9388314: 1}
# {8897375: 1}
# {11139881: 1}
# {8922954: 1}
# {9651832: 1}
# {8601100: 1}
# {7333843: 1}
# {10486674: 1}
# {654840: 1}
# {2595546: 1}
# {1196309: 1}
# {1650824: 1}
# {869305: 1}
# {1593675: 1}
# {6006885: 1}
# {3965538: 1}
# {9677803: 1}
# {11920870: 1}
# {10686499: 1}
# {1045624: 1}
# {6644524: 1}
# {9007529: 1}
# {10113026: 1}
# {9146728: 1}
# {9303798: 1}
# {5330507: 1}
# {10257944: 1}
# {6313695: 1}
# {4952904: 1}
# {5996816: 1}
# {2720456: 1}
# {1147395: 1}
# {169515: 1}
# {12078420: 1}
# {3375334: 1}
# {4789960: 1}
# {8483307: 1}
# {10017117: 1}
# {3891357: 1}
# {1214888: 1}
# {4916733: 1}
# {10241964: 1}
# {3081512: 1}
# {12080570: 1}
# {8699357: 1}
# {854759: 1}
# {8401334: 1}
# {10052671: 1}
# {3553867: 1}
# {3109863: 1}
# {847292: 1}
# {2133757: 1}
# {7543921: 1}
# {4128100: 1}
# {7803014: 1}
# {10667675: 1}
# {12984234: 1}
# {10385451: 1}
# {3002069: 1}
# {11788634: 1}
# {10250927: 1}
# {786907: 1}
# {2910325: 1}
# {6090489: 1}
# {5395077: 1}
# {5578113: 1}
# {11511447: 1}
# {10983577: 1}
# {7744123: 1}
# {9212953: 1}
# {6022055: 1}
# {9037201: 1}
# {4572401: 1}
# {3827891: 1}
# {8846524: 1}
# {11059097: 1}
# {100974: 1}
# {10396468: 1}
# {7943206: 1}
# {11194314: 1}
# {10315878: 1}
# {765789: 1}
# {10286741: 1}
# {5128551: 1}
# {10499274: 1}
# {7174908: 1}
# {10627073: 1}
# {8913976: 1}
# {7057105: 1}
# {2583537: 1}
# {5588232: 1}
# {6583383: 1}
# {6508353: 1}
# {11830169: 1}
# {11349048: 1}
# {8277336: 1}
# {10113026: 1}
# {10456093: 1}
# {7644597: 1}
# {10101359: 1}
# {2941309: 1}
# {10201139: 1}
# {4090658: 1}
# {10724997: 1}
# {11761831: 1}
# {9078637: 1}
# {7425643: 1}
# {10022894: 1}
# {9728168: 1}
# {9429026: 1}
# {3624098: 1}
# {410434: 1}
# {4755289: 1}
# {1349246: 1}
# {6090997: 1}
# {5317685: 1}
# {3734447: 1}
# {8477637: 1}
# {6568903: 1}
# {4707806: 1}
# {4525132: 1}
# {10872662: 1}
# {9604575: 1}
# {2895617: 1}
# {8346818: 1}
# {9970764: 1}
# {9533462: 1}
# {1897017: 1}
# {6487369: 1}
# {3225552: 1}
# {8160514: 1}
# {7506894: 1}
# {11019347: 1}
# {10221029: 1}
# {7987862: 1}
# {8606184: 1}
# {1560193: 1}
# {9365654: 1}
# {1651750: 1}
# {8127134: 1}
# {8423647: 1}
# {11485815: 1}
# {4686925: 1}
# {6541336: 1}
# {6738752: 1}
# {8032640: 1}
# {10759231: 1}
# {8908569: 1}
# {3017762: 1}
# {1862698: 1}
# {9997442: 1}
# {11149188: 1}
# {2270352: 1}
# {5752423: 1}
# {7736055: 1}
# {12073060: 1}
# {603920: 1}
# {10645365: 1}
# {8131096: 1}
# {3337768: 1}
# {8652771: 1}
# {10596007: 1}
# {4707285: 1}
# {10243210: 1}
# {3240377: 1}
# {8720288: 1}
# {3482044: 1}
# {6221693: 1}
# {5422420: 1}
# {8998279: 1}
# {7596848: 1}
# {7698995: 1}
# {8193628: 1}
# {9462776: 1}
# {11240745: 1}
# {265385: 1}
# {11919574: 1}
# {3747073: 1}
# {8821828: 1}
# {10187996: 1}
# {2522355: 1}
# {7764585: 1}
# {8718918: 1}
# {3996702: 1}
# {10063194: 1}
# {8443514: 1}
# {10094245: 1}
# {1829588: 1}
# {7272014: 1}
# {96306: 1}
# {6676429: 1}
# {4880617: 1}
# {9691916: 1}
# {11452327: 1}
# {1372868: 1}
# {6411891: 1}
# {6698958: 1}
# {10677875: 1}
# {7839842: 1}
# {12938735: 1}
# {6568446: 1}
# {9664868: 1}
# {10034714: 1}
# {10118807: 1}
# {3530835: 1}
# {68558: 1}
# {5873411: 1}
# {3250249: 1}
# {2996895: 1}
# {1794818: 1}
# {5440178: 1}
# {9324926: 1}
# {9986603: 1}
# {4728434: 1}
# {7778368: 1}
# {7554961: 1}
# {6723849: 1}
# {11559228: 1}
# {11772515: 1}
# {5103141: 1}
# {8101453: 1}
# {6035262: 1}
# {2997490: 1}
# {2445276: 1}
# {9942521: 1}
# {9734974: 1}
# {101879: 1}
# {7475124: 1}
# {10197609: 1}
# {1908094: 1}
# {6793208: 1}
# {1106856: 1}
# {2148105: 1}
# {6017721: 1}
# {7382675: 1}
# {9157086: 1}
# {7961665: 1}
# {1532519: 1}
# {2930546: 1}
# {5339229: 1}
# {5217224: 1}
# {8791737: 1}
# {3422552: 1}
# {7973213: 1}
# {7918581: 1}
# {1745010: 1}
# {4879403: 1}
# {1413111: 1}
# {5096628: 1}
# {2388468: 1}
# {6077846: 1}
# {8969387: 1}
# {9504842: 1}
# {2960071: 1}
# {2953255: 1}
# {5780053: 1}
# {2450063: 1}
# {1273217: 1}
# {9910867: 1}
# {2892760: 1}
# {6485472: 1}
# {8007781: 1}
# {10075751: 1}
# {5068856: 1}
# {6445101: 1}
# {5394914: 1}
# {2360762: 1}
# {487455: 1}
# {8656239: 1}
# {9327819: 1}
# {9223362: 1}
# {9226158: 1}
# {1869350: 1}
# {3618006: 1}
# {468907: 1}
# {1221719: 1}
# {6480023: 1}
# {8617803: 1}
# {5071816: 1}
# {11917435: 1}
# {10821236: 1}
# {6559274: 1}
# {8629399: 1}
# {9141682: 1}
# {7084003: 1}
# {11161285: 1}
# {1511681: 1}
# {2613063: 1}
# {8189910: 1}
# {9101953: 1}
# {2608544: 1}
# {2672245: 1}
# {7223628: 1}
# {7794101: 1}
# {9580613: 1}
# {5319703: 1}
# {8806578: 1}
# {7173822: 1}
# {5158858: 1}
# {10643102: 1}
# {8915059: 1}
# {9665121: 1}
# {5845504: 1}
# {1488083: 1}
# {12039914: 1}
# {11257507: 1}
# {6876519: 1}
# {2718387: 1}
# {9170516: 1}
# {11073872: 1}
# {5589678: 1}
# {1417031: 1}
# {2450582: 1}
# {5619538: 1}
# {6704915: 1}
# {11122570: 1}
# {10924396: 1}
# {5247342: 1}
# {2898140: 1}
# {4319980: 1}
# {7891932: 1}
# {9125524: 1}
# {3645060: 1}
# {11923698: 1}
# {6944084: 1}
# {4556714: 1}
# {8880329: 1}
# {1689473: 1}
# {4631492: 1}
# {11918777: 1}
# {3489960: 1}
# {11220618: 1}
# {1797443: 1}
# {10771079: 1}
# {10795444: 1}
# {2243744: 1}
# {3493152: 1}
# {11412401: 1}
# {8150064: 1}
# {965725: 1}
# {4360293: 1}
# {9093593: 1}
# {9150734: 1}
# {1710480: 1}
# {9281935: 1}
# {7573968: 1}
# {1355888: 1}
# {817393: 1}
# {4618132: 1}
# {4634940: 1}
# {10136239: 1}
# {9981848: 1}
# {926523: 1}
# {4467097: 1}
# {4419021: 1}
# {7650352: 1}
# {9036919: 1}
# {665313: 1}
# {2248: 1}
# {2642091: 1}
# {8508723: 1}
# {8377417: 1}
# {5900520: 1}
# {1340105: 1}
# {3709481: 1}
# {2577461: 1}
# {8927994: 1}
# {9971783: 1}
# {11751976: 1}
# {1155344: 1}
# {6652735: 1}
# {3844543: 1}
# {11147848: 1}
# {578354: 1}
# {7021099: 1}
# {8472957: 1}
# {1152143: 1}
# {9233335: 1}
# {7360520: 1}
# {8987376: 1}
# {10624119: 1}
# {8016885: 1}
# {9692926: 1}
# {873592: 1}
# {12159754: 1}
# {8378401: 1}
# {84732: 1}
# {6120339: 1}
# {9395500: 1}
# {8510143: 1}
# {9251896: 1}
# {6586628: 1}
# {1697734: 1}
# {9102801: 1}
# {8791486: 1}
# {6400215: 1}
# {12659840: 1}
# {7743571: 1}
# {3370514: 1}
# {4496416: 1}
# {8553305: 1}
# {2342365: 1}
# {3897103: 1}
# {2193487: 1}
# {2350986: 1}
# {11152298: 1}
# {1292979: 1}
# {7833541: 1}
# {11643589: 1}
# {3401262: 1}
# {6033407: 1}
# {6314884: 1}
# {6109114: 1}
# {10610299: 1}
# {11155953: 1}
# {376736: 1}
# {3615334: 1}
# {11325647: 1}
# {8048742: 1}
# {9600888: 1}
# {11987125: 1}
# {173140: 1}
# {4090501: 1}
# {4355433: 1}
# {290664: 1}
# {6683395: 1}
# {6231281: 1}
# {1585290: 1}
# {8164535: 1}
# {8808316: 1}
# {2014338: 1}
# {10392137: 1}
# {3553867: 1}
# {3469455: 1}
# {3768186: 1}
# {11533456: 1}
# {428662: 1}
# {6237126: 1}
# {8542668: 1}
# {2444841: 1}
# {904015: 1}
# {7402445: 1}
# {9754766: 1}
# {2113710: 1}
# {2464327: 1}
# {1723746: 1}
# {3970466: 1}
# {11305051: 1}
# {791850: 1}
# {7106394: 1}
# {5939953: 1}
# {5618528: 1}
# {11384922: 1}
# {11711334: 1}
# {7105787: 1}
# {6920518: 1}
# {10404609: 1}
# {8864523: 1}
# {5413868: 1}
# {10923159: 1}
# {1074163: 1}
# {3280922: 1}
# {2967782: 1}
# {6380401: 1}
# {11717821: 1}
# {2614232: 1}
# {1265392: 1}
# {10729224: 1}
# {10809217: 1}
# {3910356: 1}
# {1373799: 1}
# {4910019: 1}
# {10462842: 1}
# {5886403: 1}
# {4642586: 1}
# {6727908: 1}
# {9507437: 1}
# {10770443: 1}
# {58552: 1}
# {12948413: 1}
# {2489170: 1}
# {625746: 1}
# {4039513: 1}
# {9630385: 1}
# {4724966: 1}
# {7949611: 1}
# {5220166: 1}
# recommended for 1000 users
# {8239287: 1}
# {8650595: 1}
# {10437323: 1}
# {7555144: 1}
# {3372390: 1}
# {2140: 1}
# {9390856: 1}
# {8911790: 1}
# {10262128: 1}
# {10501211: 1}
# {1552271: 1}
# {3188598: 1}
# {4277812: 1}
# {7024154: 1}
# {3761556: 1}
# {3573650: 1}
# {8907043: 1}
# {5094589: 1}
# {9222474: 1}
# {8369721: 1}
# {5369445: 1}
# {10301480: 1}
# {9722048: 1}
# {6687978: 1}
# {5350178: 1}
# {10354723: 1}
# {7763559: 1}
# {9781317: 1}
# {449221: 1}
# {5567120: 1}
# {11833289: 1}
# {6514908: 1}
# {9878560: 1}
# {12046979: 1}
# {6644091: 1}
# {4279464: 1}
# {6822183: 1}
# {5111912: 1}
# {7541697: 1}
# {3432499: 1}
# {5559404: 1}
# {5501052: 1}
# {8727041: 1}
# {11107148: 1}
# {10903671: 1}
# {10764878: 1}
# {2538121: 1}
# {1955767: 1}
# {7662364: 1}
# {957800: 1}
# {8712682: 1}
# {10085575: 1}
# {11482113: 1}
# {4676563: 1}
# {8254965: 1}
# {10340186: 1}
# {2191537: 1}
# {7558315: 1}
# {1581457: 1}
# {10458754: 1}
# {8080130: 1}
# {6231407: 1}
# {10023731: 1}
# {834015: 1}
# {7089255: 1}
# {4075687: 1}
# {10905532: 1}
# {2197593: 1}
# {11966232: 1}
# {4323375: 1}
# {5517046: 1}
# {6523056: 1}
# {9523842: 1}
# {8486480: 1}
# {8868556: 1}
# {11639766: 1}
# {10684615: 1}
# {9533425: 1}
# {5499803: 1}
# {9233335: 1}
# {405418: 1}
# {6100617: 1}
# {9208548: 1}
# {5758439: 1}
# {10453949: 1}
# {6785404: 1}
# {7026384: 1}
# {7973320: 1}
# {11688080: 1}
# {7485720: 1}
# {6218326: 1}
# {10534110: 1}
# {2029359: 1}
# {1623650: 1}
# {5446665: 1}
# {1786284: 1}
# {3123922: 1}
# {6727713: 1}
# {2382317: 1}
# {7971993: 1}
# {231738: 1}
# {8879649: 1}
# {10223597: 1}
# {10418786: 1}
# {7844084: 1}
# {6907806: 1}
# {8361014: 1}
# {8209039: 1}
# {1560289: 1}
# {4177106: 1}
# {1380195: 1}
# {9417158: 1}
# {7692433: 1}
# {9988933: 1}
# {5913921: 1}
# {8964781: 1}
# {4850992: 1}
# {10941312: 1}
# {9963499: 1}
# {5106888: 1}
# {6397077: 1}
# {11732661: 1}
# {11193545: 1}
# {4714853: 1}
# {6719456: 1}
# {11982654: 1}
# {3645200: 1}
# {4266388: 1}
# {8454588: 1}
# {3963446: 1}
# {672632: 1}
# {5208536: 1}
# {11954324: 1}
# {6173986: 1}
# {2330622: 1}
# {304377: 1}
# {393842: 1}
# {5968188: 1}
# {7482259: 1}
# {9146037: 1}
# {2711235: 1}
# {11221714: 1}
# {1940889: 1}
# {5453474: 1}
# {84015: 1}
# {5429331: 1}
# {3585479: 1}
# {1600439: 1}
# {5163709: 1}
# {1238705: 1}
# {3918038: 1}
# {8602741: 1}
# {8603859: 1}
# {5977208: 1}
# {1827521: 1}
# {10608184: 1}
# {4420682: 1}
# {2679247: 1}
# {11897903: 1}
# {9176188: 1}
# {8997341: 1}
# {11271996: 1}
# {7087116: 1}
# {4023868: 1}
# {4070809: 1}
# {4848097: 1}
# {9423155: 1}
# {979229: 1}
# {11144758: 1}
# {643906: 1}
# {10094245: 1}
# {10308306: 1}
# {10456280: 1}
# {1497242: 1}
# {10758629: 1}
# {5506462: 1}
# {11476096: 1}
# {7416504: 1}
# {6596771: 1}
# {11558118: 1}
# {4942275: 1}
# {9183091: 1}
# {9917770: 1}
# {6758619: 1}
# {8672027: 1}
# {7722746: 1}
# {275663: 1}
# {4236932: 1}
# {4962167: 1}
# {8179047: 1}
# {6034580: 1}
# {8994427: 1}
# {9026310: 1}
# {3513652: 1}
# {6323243: 1}
# {9314082: 1}
# {8864523: 1}
# {9346840: 1}
# {11013218: 1}
# {8833413: 1}
# {8828448: 1}
# {7334110: 1}
# {10503833: 1}
# {6236213: 1}
# {8541096: 1}
# {10638981: 1}
# {556490: 1}
# {10825803: 1}
# {4335837: 1}
# {10969090: 1}
# {9271069: 1}
# {9147433: 1}
# {4665681: 1}
# {2681313: 1}
# {11375270: 1}
# {9274464: 1}
# {9711280: 1}
# {9478150: 1}
# {7769696: 1}
# {7780662: 1}
# {7935550: 1}
# {9579740: 1}
# {10972811: 1}
# {6877910: 1}
# {9424257: 1}
# {9343436: 1}
# {367356: 1}
# {3845079: 1}
# {8987360: 1}
# {11717821: 1}
# {5497091: 1}
# {7179000: 1}
# {8391415: 1}
# {9518795: 1}
# {4278976: 1}
# {5314828: 1}
# {7026296: 1}
# {7823107: 1}
# {7478193: 1}
# {7569009: 1}
# {11322115: 1}
# {4613283: 1}
# {9294609: 1}
# {607824: 1}
# {11239539: 1}
# {4742311: 1}
# {6423028: 1}
# {11717821: 1}
# {11820890: 1}
# {5382324: 1}
# {2163131: 1}
# {8069835: 1}
# {8994851: 1}
# {12993721: 1}
# {10782569: 1}
# {5549850: 1}
# {9353114: 1}
# {11291525: 1}
# {801185: 1}
# {10002875: 1}
# {388070: 1}
# {10672846: 1}
# {4861343: 1}
# {723686: 1}
# {11888496: 1}
# {1008395: 1}
# {5089377: 1}
# {9291481: 1}
# {8406181: 1}
# {8219143: 1}
# {4202487: 1}
# {11293837: 1}
# {3798695: 1}
# {11230481: 1}
# {431020: 1}
# {1930940: 1}
# {4183239: 1}
# {6122850: 1}
# {10606721: 1}
# {10684971: 1}
# {4413657: 1}
# {1816036: 1}
# {10175490: 1}
# {8277336: 1}
# {5536916: 1}
# {8899627: 1}
# {9235254: 1}
# {5236992: 1}
# {9951478: 1}
# {3953436: 1}
# {1179804: 1}
# {8443494: 1}
# {4382017: 1}
# {2543511: 1}
# {4307666: 1}
# {8755974: 1}
# {8080760: 1}
# {4552325: 1}
# {953034: 1}
# {1666836: 1}
# {12199198: 1}
# {10451689: 1}
# {5687553: 1}
# {7617941: 1}
# {11605750: 1}
# {11097327: 1}
# {7601087: 1}
# {3143907: 1}
# {7293416: 1}
# {2758207: 1}
# {1449447: 1}
# {6887593: 1}
# {1322: 1}
# {6662310: 1}
# {6555855: 1}
# {2299157: 1}
# {7121557: 1}
# {1194068: 1}
# {7418933: 1}
# {4109726: 1}
# {171781: 1}
# {11717821: 1}
# {1933005: 1}
# {750619: 1}
# {8391083: 1}
# {11164654: 1}
# {11648790: 1}
# {6949116: 1}
# {7677966: 1}
# {2098597: 1}
# {9890796: 1}
# {7280827: 1}
# {9077561: 1}
# {2041123: 1}
# {5700583: 1}
# {6007466: 1}
# {3553867: 1}
# {2058330: 1}
# {2812976: 1}
# {2777598: 1}
# {6503951: 1}
# {2568896: 1}
# {4850839: 1}
# {9691542: 1}
# {618047: 1}
# {1939453: 1}
# {7000690: 1}
# {2004809: 1}
# {9488363: 1}
# {8996127: 1}
# {3282030: 1}
# {6920565: 1}
# {3092003: 1}
# {8920468: 1}
# {2296619: 1}
# {11823891: 1}
# {7277859: 1}
# {8128276: 1}
# {3178183: 1}
# {10068307: 1}
# {11330076: 1}
# {11717816: 1}
# {2931477: 1}
# {10382119: 1}
# {2774166: 1}
# {9515783: 1}
# {3917416: 1}
# {2166597: 1}
# {2635159: 1}
# {6925854: 1}
# {11391626: 1}
# {8018028: 1}
# {9420921: 1}
# {4852887: 1}
# {1096653: 1}
# {8510143: 1}
# {9025393: 1}
# {7706675: 1}
# {8688108: 1}
# {2556025: 1}
# {5357017: 1}
# {5062281: 1}
# {2334611: 1}
# {2895520: 1}
# {2788479: 1}
# {8951229: 1}
# {5352175: 1}
# {10887464: 1}
# {4423827: 1}
# {9540924: 1}
# {437710: 1}
# {7611313: 1}
# {9273969: 1}
# {4677226: 1}
# {10650261: 1}
# {9137431: 1}
# {11088820: 1}
# {1836445: 1}
# {6383028: 1}
# {9170247: 1}
# {5416734: 1}
# {129232: 1}
# {9639732: 1}
# {7592886: 1}
# {1532693: 1}
# {3725270: 1}
# {1763171: 1}
# {9358148: 1}
# {1359228: 1}
# {4006417: 1}
# {2997203: 1}
# {5478134: 1}
# {7498078: 1}
# {7855215: 1}
# {9354096: 1}
# {800651: 1}
# {7617886: 1}
# {436909: 1}
# {2780058: 1}
# {9043379: 1}
# {8232780: 1}
# {3169289: 1}
# {11456673: 1}
# {3184178: 1}
# {5028425: 1}
# {7902623: 1}
# {2465867: 1}
# {7816456: 1}
# {6411668: 1}
# {7403194: 1}
# {6731826: 1}
# {9977282: 1}
# {10457533: 1}
# {6780386: 1}
# {7412557: 1}
# {12937659: 1}
# {7210675: 1}
# {11484187: 1}
# {6916838: 1}
# {1717823: 1}
# {2146522: 1}
# {1280150: 1}
# {5410026: 1}
# {10312571: 1}
# {9777056: 1}
# {10517552: 1}
# {496447: 1}
# {4924436: 1}
# {8910002: 1}
# {6383282: 1}
# {1557619: 1}
# {7993304: 1}
# {12879797: 1}
# {7793992: 1}
# {8515413: 1}
# {10822725: 1}
# {6020455: 1}
# {5326227: 1}
# {6070132: 1}
# {3455247: 1}
# {7069116: 1}
# {4267955: 1}
# {5238826: 1}
# {6100991: 1}
# {1389971: 1}
# {9079383: 1}
# {1295319: 1}
# {6110116: 1}
# {8874989: 1}
# {1852559: 1}
# {5722578: 1}
# {11376851: 1}
# {5739422: 1}
# {8862991: 1}
# {3447909: 1}
# {12141319: 1}
# {9134170: 1}
# {1740871: 1}
# {8967377: 1}
# {3727679: 1}
# {7901569: 1}
# {2394400: 1}
# {1164317: 1}
# {10259345: 1}
# {1294279: 1}
# {2759721: 1}
# {4795084: 1}
# {12154033: 1}
# {7761631: 1}
# {324904: 1}
# {6502004: 1}
# {332772: 1}
# {10229493: 1}
# {8003268: 1}
# {10726814: 1}
# {6781559: 1}
# {8413258: 1}
# {10854130: 1}
# {11323052: 1}
# {6107940: 1}
# recommended for 1500 users
# {1260008: 1}
# {2831474: 1}
# {4583308: 1}
# {7402713: 1}
# {7723397: 1}
# {9546813: 1}
# {7535052: 1}
# {7793992: 1}
# {239173: 1}
# {10312377: 1}
# {5716737: 1}
# {5982802: 1}
# {7896488: 1}
# {3727965: 1}
# {1529965: 1}
# {5607460: 1}
# {611267: 1}
# {753241: 1}
# {8486452: 1}
# {11222448: 1}
# {8387474: 1}
# {10690490: 1}
# {5204721: 1}
# {2130573: 1}
# {3110375: 1}
# {9176457: 1}
# {8469493: 1}
# {9759528: 1}
# {3328711: 1}
# {5750100: 1}
# {6667696: 1}
# {811111: 1}
# {8846311: 1}
# {9282468: 1}
# {5867257: 1}
# {4661449: 1}
# {7715380: 1}
# {2217681: 1}
# {7887997: 1}
# {9608457: 1}
# {3471268: 1}
# {8980538: 1}
# {251461: 1}
# {8454436: 1}
# {5674791: 1}
# {9869840: 1}
# {9450202: 1}
# {6540420: 1}
# {2805285: 1}
# {1311111: 1}
# {2785459: 1}
# {1534263: 1}
# {6911354: 1}
# {11996222: 1}
# {5663036: 1}
# {9235938: 1}
# {9635218: 1}
# {3290088: 1}
# {10911080: 1}
# {5680634: 1}
# {9336696: 1}
# {6294691: 1}
# {12816829: 1}
# {1733720: 1}
# {3413791: 1}
# {6489252: 1}
# {3513092: 1}
# {3340409: 1}
# {7925368: 1}
# {7149359: 1}
# {6122377: 1}
# {1988039: 1}
# {6643599: 1}
# {3692046: 1}
# {7217705: 1}
# {10166752: 1}
# {3456575: 1}
# {9923220: 1}
# {6090416: 1}
# {1410198: 1}
# {1003480: 1}
# {2072831: 1}
# {6426586: 1}
# {8246287: 1}
# {3698144: 1}
# {7215773: 1}
# {1270284: 1}
# {10651268: 1}
# {5606919: 1}
# {8773016: 1}
# {7830689: 1}
# {3029661: 1}
# {6180180: 1}
# {4852255: 1}
# {3453226: 1}
# {7550926: 1}
# {4913911: 1}
# {10399742: 1}
# {9585682: 1}
# {10464898: 1}
# {6044354: 1}
# {1192286: 1}
# {8827487: 1}
# {9213774: 1}
# {11291525: 1}
# {929658: 1}
# {5634792: 1}
# {81444: 1}
# {9524037: 1}
# {8396609: 1}
# {1555198: 1}
# {9966615: 1}
# {12118845: 1}
# {9193733: 1}
# {6509953: 1}
# {289667: 1}
# {8788074: 1}
# {694294: 1}
# {1714998: 1}
# {9987985: 1}
# {3331869: 1}
# {3995666: 1}
# {9134153: 1}
# {10209265: 1}
# {9891817: 1}
# {7851468: 1}
# {12067278: 1}
# {9638711: 1}
# {9088784: 1}
# {4158692: 1}
# {8899019: 1}
# {12159254: 1}
# {2951407: 1}
# {4399996: 1}
# {8844287: 1}
# {5456198: 1}
# {4370821: 1}
# {5756401: 1}
# {9694139: 1}
# {4559326: 1}
# {9070591: 1}
# {11843557: 1}
# {631405: 1}
# {2668595: 1}
# {4058165: 1}
# {5076402: 1}
# {9100513: 1}
# {5545218: 1}
# {10688781: 1}
# {11629514: 1}
# {9100419: 1}
# {6853878: 1}
# {6801708: 1}
# {5250957: 1}
# {9019047: 1}
# {7464405: 1}
# {9178438: 1}
# {10783127: 1}
# {1300765: 1}
# {3838560: 1}
# {9790625: 1}
# {5333054: 1}
# {8464297: 1}
# {2258403: 1}
# {2285733: 1}
# {5429937: 1}
# {2740355: 1}
# {3827511: 1}
# {3476961: 1}
# {11239001: 1}
# {8591886: 1}
# {11354309: 1}
# {3977855: 1}
# {7502098: 1}
# {1043077: 1}
# {3753112: 1}
# {10251476: 1}
# {1450033: 1}
# {3511052: 1}
# {4480512: 1}
# {2611032: 1}
# {10581397: 1}
# {9516159: 1}
# {11700200: 1}
# {8479091: 1}
# {10897737: 1}
# {4383394: 1}
# {8380516: 1}
# {5383757: 1}
# {3078594: 1}
# {3236540: 1}
# {413921: 1}
# {7850315: 1}
# {947767: 1}
# {9241356: 1}
# {3308028: 1}
# {3473322: 1}
# {8108482: 1}
# {5091906: 1}
# {2940434: 1}
# {9718286: 1}
# {9002211: 1}
# {6089604: 1}
# {1722945: 1}
# {6053102: 1}
# {9322727: 1}
# {462517: 1}
# {1522922: 1}
# {10331718: 1}
# {5097712: 1}
# {4239830: 1}
# {403894: 1}
# {11415161: 1}
# {9852389: 1}
# {4727839: 1}
# {9848749: 1}
# {3930011: 1}
# {5262693: 1}
# {546594: 1}
# {5171408: 1}
# {9047042: 1}
# {7994242: 1}
# {259146: 1}
# {9863053: 1}
# {8690587: 1}
# {1208632: 1}
# {11825988: 1}
# {7057676: 1}
# {9994328: 1}
# {7556375: 1}
# {1916371: 1}
# {9319238: 1}
# {3997006: 1}
# {10219898: 1}
# {4146852: 1}
# {7791375: 1}
# {8863450: 1}
# {3035249: 1}
# {557307: 1}
# {4862330: 1}
# {8965321: 1}
# {11986105: 1}
# {6342913: 1}
# {5146154: 1}
# {10931216: 1}
# {1868582: 1}
# {7411596: 1}
# {2033293: 1}
# {9715746: 1}
# {10330555: 1}
# {9628246: 1}
# {12877155: 1}
# {9673500: 1}
# {10855968: 1}
# {12966025: 1}
# {8826246: 1}
# {7505209: 1}
# {6606826: 1}
# {2608255: 1}
# {6077454: 1}
# {3778104: 1}
# {8520448: 1}
# {6500059: 1}
# {497416: 1}
# {946785: 1}
# {9345543: 1}
# {8130922: 1}
# {7993965: 1}
# {3782911: 1}
# {2785459: 1}
# {4908233: 1}
# {8922929: 1}
# {9078666: 1}
# {10770051: 1}
# {11448753: 1}
# {3448932: 1}
# {1389833: 1}
# {12208392: 1}
# {12938735: 1}
# {9900798: 1}
# {6025215: 1}
# {1493582: 1}
# {11381590: 1}
# {10789848: 1}
# {6635807: 1}
# {8641291: 1}
# {7334003: 1}
# {3666158: 1}
# {8267841: 1}
# {11029902: 1}
# {76171: 1}
# {10774549: 1}
# {7571745: 1}
# {10946161: 1}
# {8671629: 1}
# {5360164: 1}
# {8819299: 1}
# {8960937: 1}
# {11533456: 1}
# {3615616: 1}
# {7963747: 1}
# {409523: 1}
# {7647288: 1}
# {9608848: 1}
# {118891: 1}
# {9210134: 1}
# {5825537: 1}
# {7877369: 1}
# {10364644: 1}
# {4263635: 1}
# {11209378: 1}
# {8548537: 1}
# {3398186: 1}
# {4448789: 1}
# {6865046: 1}
# {9168655: 1}
# {9324329: 1}
# {10821024: 1}
# {4647009: 1}
# {1793539: 1}
# {9172472: 1}
# {1576390: 1}
# {8808316: 1}
# {4985913: 1}
# {11090385: 1}
# {8962361: 1}
# {11798458: 1}
# {121659: 1}
# {10242057: 1}
# {3541786: 1}
# {3880909: 1}
# {8280910: 1}
# {1815063: 1}
# {2504562: 1}
# {5587243: 1}
# {11807223: 1}
# {1235493: 1}
# {2958064: 1}
# {1798702: 1}
# {9950009: 1}
# {9570255: 1}
# {11376926: 1}
# {3839757: 1}
# {1977549: 1}
# {942981: 1}
# {4728812: 1}
# {7277113: 1}
# {7822238: 1}
# {11384469: 1}
# {4546511: 1}
# {7521360: 1}
# {8828901: 1}
# {7649367: 1}
# {8472827: 1}
# {11783650: 1}
# {5926172: 1}
# {10600375: 1}
# {7873390: 1}
# {6801476: 1}
# {5259939: 1}
# {8058964: 1}
# {9866360: 1}
# {6614315: 1}
# {7113495: 1}
# {7473576: 1}
# {6096757: 1}
# {11955734: 1}
# {2925777: 1}
# {6047221: 1}
# {3132291: 1}
# {12640976: 1}
# {10926997: 1}
# {8424491: 1}
# {12128678: 1}
# {11628761: 1}
# {10868663: 1}
# {201316: 1}
# {1114473: 1}
# {10788052: 1}
# {8791855: 1}
# {4978163: 1}
# {1019137: 1}
# {4767901: 1}
# {5171696: 1}
# {8050055: 1}
# {10210980: 1}
# {2885440: 1}
# {4723867: 1}
# {1899340: 1}
# {6051900: 1}
# {10224522: 1}
# {11253334: 1}
# {4922421: 1}
# {257002: 1}
# {8166872: 1}
# {9651782: 1}
# {11747948: 1}
# {5612660: 1}
# {6269501: 1}
# {1253536: 1}
# {8429433: 1}
# {4982278: 1}
# {3553010: 1}
# {7122593: 1}
# {3337768: 1}
# {4344054: 1}
# {4912060: 1}
# {4459387: 1}
# {7548882: 1}
# {7643932: 1}
# {10751978: 1}
# {7039055: 1}
# {6534453: 1}
# {11633286: 1}
# {2659032: 1}
# {9669390: 1}
# {6695528: 1}
# {10158779: 1}
# {12877155: 1}
# {7001483: 1}
# {8534663: 1}
# {6340732: 1}
# {1176610: 1}
# {9301834: 1}
# {11497096: 1}
# {6003818: 1}
# {875066: 1}
# {4263535: 1}
# {10469572: 1}
# {8194052: 1}
# {11396352: 1}
# {5829176: 1}
# {6978699: 1}
# {10569386: 1}
# {6514229: 1}
# {5749470: 1}
# {8827799: 1}
# {2569735: 1}
# {1469609: 1}
# {3571922: 1}
# {10490888: 1}
# {8553810: 1}
# {4830694: 1}
# {10821465: 1}
# {6725386: 1}
# {4050927: 1}
# {4544012: 1}
# {3517117: 1}
# {9910811: 1}
# {6182759: 1}
# {6468919: 1}
# {3568338: 1}
# {11591947: 1}
# {8758472: 1}
# {9485505: 1}
# {8494504: 1}
# {8205731: 1}
# {12985975: 1}
# {2514144: 1}
# {10533065: 1}
# {7216663: 1}
# {10469818: 1}
# {5042357: 1}
# {11452942: 1}
# {997466: 1}
# {3996702: 1}
# {12060237: 1}
# {7734952: 1}
# {1615129: 1}
# {3262117: 1}
# {737736: 1}
# {6661755: 1}
# {5873609: 1}
# {11559386: 1}
# {11492068: 1}
# {6335269: 1}
# {1929851: 1}
# {6887593: 1}
# {1881490: 1}
# {11405980: 1}
# {3160002: 1}
# {9626129: 1}
# {8526708: 1}
# {2697823: 1}
# {11148021: 1}
# {1855292: 1}
# {9988892: 1}
# {5913155: 1}
# {9572565: 1}
# {7010068: 1}
# {8324113: 1}
# {9043251: 1}
# {1588124: 1}
# {5645154: 1}
# {10254172: 1}
# {6429699: 1}
# {9121671: 1}
# {7297146: 1}
# {5739422: 1}
# {9065254: 1}
# recommended for 2000 users
# {10445011: 1}
# {10469167: 1}
# {10363848: 1}
# {11242538: 1}
# {3267198: 1}
# {4613175: 1}
# {5410931: 1}
# {9994244: 1}
# {10309150: 1}
# {327870: 1}
# {7543310: 1}
# {3731548: 1}
# {600012: 1}
# {4426984: 1}
# {8175847: 1}
# {10557317: 1}
# {12084766: 1}
# {13001451: 1}
# {2236565: 1}
# {10791429: 1}
# {10250220: 1}
# {8335211: 1}
# {4523363: 1}
# {2382525: 1}
# {7847145: 1}
# {7057391: 1}
# {2387646: 1}
# {3183871: 1}
# {6175147: 1}
# {9623548: 1}
# {6116444: 1}
# {2719172: 1}
# {6095959: 1}
# {7595324: 1}
# {12956807: 1}
# {8834769: 1}
# {6047539: 1}
# {1059485: 1}
# {6259893: 1}
# {1575940: 1}
# {20041: 1}
# {2493014: 1}
# {7229147: 1}
# {7623659: 1}
# {11646340: 1}
# {11366380: 1}
# {10405906: 1}
# {2072096: 1}
# {10066546: 1}
# {844325: 1}
# {7375913: 1}
# {11168529: 1}
# {6694799: 1}
# {10527999: 1}
# {7850777: 1}
# {7013597: 1}
# {1742373: 1}
# {3064031: 1}
# {2150248: 1}
# {4271861: 1}
# {7323542: 1}
# {11384469: 1}
# {9821042: 1}
# {7118019: 1}
# {9932432: 1}
# {9299908: 1}
# {10012768: 1}
# {2902785: 1}
# {1192286: 1}
# {26072: 1}
# {1686565: 1}
# {9175878: 1}
# {10638479: 1}
# {11880132: 1}
# {11220223: 1}
# {454939: 1}
# {2539812: 1}
# {8911667: 1}
# {5897235: 1}
# {10358079: 1}
# {10634664: 1}
# {4070122: 1}
# {10557796: 1}
# {5612333: 1}
# {6102681: 1}
# {1517204: 1}
# {7067736: 1}
# {3601152: 1}
# {7910796: 1}
# {6069041: 1}
# {3718084: 1}
# {8018028: 1}
# {6494083: 1}
# {270180: 1}
# {5977062: 1}
# {4173141: 1}
# {8286405: 1}
# {6651097: 1}
# {8642029: 1}
# {1092237: 1}
# {2437265: 1}
# {9432502: 1}
# {5233889: 1}
# {11717821: 1}
# {10729115: 1}
# {10274405: 1}
# {2209873: 1}
# {10288966: 1}
# {154542: 1}
# {7586677: 1}
# {5654819: 1}
# {12033731: 1}
# {5716827: 1}
# {10810498: 1}
# {2998513: 1}
# {2941781: 1}
# {5021475: 1}
# {5976947: 1}
# {9657036: 1}
# {10868663: 1}
# {11813288: 1}
# {2996335: 1}
# {704099: 1}
# {1847750: 1}
# {6560132: 1}
# {10450587: 1}
# {9104823: 1}
# {8111411: 1}
# {10434774: 1}
# {1095015: 1}
# {11460680: 1}
# {5885987: 1}
# {7105787: 1}
# {1410535: 1}
# {8198996: 1}
# {4988922: 1}
# {5972125: 1}
# {4988625: 1}
# {3433257: 1}
# {4062057: 1}
# {5229873: 1}
# {7533238: 1}
# {3862456: 1}
# {3343287: 1}
# {3875116: 1}
# {11381019: 1}
# {9536391: 1}
# {3660746: 1}
# {902937: 1}
# {12010549: 1}
# {2556025: 1}
# {7116010: 1}
# {6364511: 1}
# {9009189: 1}
# {7206764: 1}
# {7238897: 1}
# {9517584: 1}
# {7772150: 1}
# {10632282: 1}
# {7608919: 1}
# {8442888: 1}
# {10076389: 1}
# {5060730: 1}
# {7625420: 1}
# {2201180: 1}
# {2099207: 1}
# {10813989: 1}
# {5378003: 1}
# {8253305: 1}
# {7973096: 1}
# {9816973: 1}
# {7946259: 1}
# {6969764: 1}
# {8528293: 1}
# {11322516: 1}
# {9196130: 1}
# {3538134: 1}
# {3775697: 1}
# {6364901: 1}
# {3442110: 1}
# {11918738: 1}
# {8664710: 1}
# {1988345: 1}
# {8281018: 1}
# {11324639: 1}
# {5410689: 1}
# {7119549: 1}
# {1728519: 1}
# {7043667: 1}
# {12663630: 1}
# {10803551: 1}
# {11700329: 1}
# {1019137: 1}
# {8147999: 1}
# {10074514: 1}
# {6997477: 1}
# {1322699: 1}
# {10993572: 1}
# {4270259: 1}
# {1807824: 1}
# {7550926: 1}
# {7803788: 1}
# {9824353: 1}
# {9111923: 1}
# {2178121: 1}
# {5866048: 1}
# {6395722: 1}
# {1583187: 1}
# {2975897: 1}
# {5620737: 1}
# {3977437: 1}
# {8843476: 1}
# {2533557: 1}
# {8484719: 1}
# {9495852: 1}
# {2419871: 1}
# {4677921: 1}
# {6498659: 1}
# {9809289: 1}
# {9009273: 1}
# {9346865: 1}
# {10583763: 1}
# {205436: 1}
# {1601858: 1}
# {203396: 1}
# {8794830: 1}
# {8086124: 1}
# {11167672: 1}
# {3584382: 1}
# {8820011: 1}
# {10087830: 1}
# {7080250: 1}
# {1535570: 1}
# {10909021: 1}
# {3891897: 1}
# {8876360: 1}
# {7666099: 1}
# {1853423: 1}
# {3182226: 1}
# {565286: 1}
# {3006370: 1}
# {4419327: 1}
# {5179933: 1}
# {5519164: 1}
# {9759016: 1}
# {12640943: 1}
# {5195664: 1}
# {1655390: 1}
# {1848053: 1}
# {7014586: 1}
# {5064497: 1}
# {662320: 1}
# {6249593: 1}
# {10807751: 1}
# {7754042: 1}
# {4355433: 1}
# {2270688: 1}
# {5892287: 1}
# {7136358: 1}
# {6364744: 1}
# {7265081: 1}
# {2623829: 1}
# {3250661: 1}
# {10199345: 1}
# {726660: 1}
# {9267778: 1}
# {5197858: 1}
# {2294968: 1}
# {11197392: 1}
# {3281931: 1}
# {11371387: 1}
# {8725143: 1}
# {2170566: 1}
# {10337332: 1}
# {5447102: 1}
# {10663169: 1}
# {1337296: 1}
# {5813776: 1}
# {1720753: 1}
# {11289540: 1}
# {7743271: 1}
# {11217409: 1}
# {10754905: 1}
# {11806174: 1}
# {1205281: 1}
# {1171227: 1}
# {8755072: 1}
# {8900086: 1}
# {1310235: 1}
# {8252080: 1}
# {11879555: 1}
# {9439148: 1}
# {7801551: 1}
# {3406209: 1}
# {2317887: 1}
# {11870212: 1}
# {5953033: 1}
# {3779191: 1}
# {1094319: 1}
# {4010866: 1}
# {7449358: 1}
# {5932962: 1}
# {9529129: 1}
# {3553867: 1}
# {1091336: 1}
# {6822419: 1}
# {4496186: 1}
# {5477783: 1}
# {9181875: 1}
# {5703187: 1}
# {9766940: 1}
# {11591220: 1}
# {7941028: 1}
# {5886962: 1}
# {8399755: 1}
# {10120244: 1}
# {2121171: 1}
# {5861605: 1}
# {10523631: 1}
# {983718: 1}
# {7143239: 1}
# {2837628: 1}
# {3702047: 1}
# {6040937: 1}
# {10932244: 1}
# {6096342: 1}
# {3996702: 1}
# {11291118: 1}
# {5809898: 1}
# {4009426: 1}
# {654840: 1}
# {7393120: 1}
# {3641427: 1}
# {7401102: 1}
# {9949591: 1}
# {4132043: 1}
# {5377236: 1}
# {4498115: 1}
# {94758: 1}
# {11498171: 1}
# {2556025: 1}
# {3630276: 1}
# {12270076: 1}
# {2998845: 1}
# {7793642: 1}
# {4145169: 1}
# {11585743: 1}
# {10381191: 1}
# {12878628: 1}
# {568577: 1}
# {10190528: 1}
# {10800555: 1}
# {555274: 1}
# {8713554: 1}
# {4955041: 1}
# {9515326: 1}
# {9146720: 1}
# {9301458: 1}
# {8916553: 1}
# {1885771: 1}
# {11580967: 1}
# {11608745: 1}
# {7430477: 1}
# {6544529: 1}
# {7442305: 1}
# {8857933: 1}
# {5109320: 1}
# {10359069: 1}
# {11742806: 1}
# {2566862: 1}
# {4186930: 1}
# {8212858: 1}
# {10860404: 1}
# {9241356: 1}
# {5658752: 1}
# {1482396: 1}
# {3515598: 1}
# {9355210: 1}
# {5456895: 1}
# {10973542: 1}
# {2590745: 1}
# {2679201: 1}
# {11535751: 1}
# {11054130: 1}
# {4378445: 1}
# {10282451: 1}
# {6676695: 1}
# {3731194: 1}
# {5327692: 1}
# {6541967: 1}
# {5919895: 1}
# {11533456: 1}
# {10160455: 1}
# {6994540: 1}
# {7891583: 1}
# {5193037: 1}
# {618833: 1}
# {9804925: 1}
# {437710: 1}
# {11791301: 1}
# {8278748: 1}
# {7563183: 1}
# {11980433: 1}
# {11134797: 1}
# {5713160: 1}
# {2191537: 1}
# {3794136: 1}
# {7941456: 1}
# {3280628: 1}
# {9790462: 1}
# {12120132: 1}
# {10426931: 1}
# {6435926: 1}
# {9938439: 1}
# {8366461: 1}
# {8454102: 1}
# {10527946: 1}
# {9320246: 1}
# {6259237: 1}
# {9966661: 1}
# {6553462: 1}
# {6899024: 1}
# {217074: 1}
# {6536206: 1}
# {2518386: 1}
# {10559727: 1}
# {4134726: 1}
# {10749378: 1}
# {11921053: 1}
# {9132071: 1}
# {10208980: 1}
# {5666530: 1}
# {10130004: 1}
# {7409572: 1}
# {7110454: 1}
# {9913150: 1}
# {8693110: 1}
# {7253693: 1}
# {6283374: 1}
# {1091336: 1}
# {4967533: 1}
# {10137050: 1}
# {10461095: 1}
# {5288368: 1}
# {4311396: 1}
# {4667910: 1}
# {12120132: 1}
# {7693355: 1}
# {4714884: 1}
# {7616270: 1}
# {10636176: 1}
# {9336628: 1}
# {11658201: 1}
# {4514780: 1}
# {11821350: 1}
# {8796634: 1}
# {8592694: 1}
# {1736392: 1}
# {10776323: 1}
# {12120132: 1}
# {7813172: 1}
# {9481610: 1}
# {7629451: 1}
# {4611744: 1}
# {7016541: 1}
# {9293058: 1}
# {3311153: 1}
# {2035803: 1}
# {7423999: 1}
# {10516392: 1}
# {10392340: 1}
# {4015006: 1}
# {5019127: 1}
# {3335126: 1}
# {10517552: 1}
# {4695682: 1}
# {2962958: 1}
# {1164754: 1}
# {8062252: 1}
# {3823870: 1}
# {6591756: 1}
# {4341353: 1}
# {10360793: 1}
# {10998391: 1}
# {5280999: 1}
# {8721348: 1}
# {8309996: 1}
# {2314004: 1}
# {8978013: 1}
# {10715912: 1}
# {1523315: 1}
# {489668: 1}
# {9002957: 1}
# {8605764: 1}
# {6994492: 1}
# {10837282: 1}
# {2937: 1}
# {8032981: 1}
# {9697267: 1}
# {11862483: 1}
# recommended for 2500 users
# {427268: 1}
# {10316923: 1}
# {7412272: 1}
# {657157: 1}
# {1573104: 1}
# {220787: 1}
# {7586519: 1}
# {13045331: 1}
# {448822: 1}
# {2446909: 1}
# {4611017: 1}
# {644844: 1}
# {12972119: 1}
# {695522: 1}
# {3207573: 1}
# {5438036: 1}
# {2556025: 1}
# {6388618: 1}
# {1669104: 1}
# {9776214: 1}
# {54617: 1}
# {1289859: 1}
# {9839929: 1}
# {5415487: 1}
# {10826891: 1}
# {10424342: 1}
# {200834: 1}
# {3930413: 1}
# {5938224: 1}
# {11680535: 1}
# {11344644: 1}
# {927180: 1}
# {12964832: 1}
# {12271015: 1}
# {4858075: 1}
# {10783884: 1}
# {8862288: 1}
# {11870354: 1}
# {2363133: 1}
# {9250457: 1}
# {9450727: 1}
# {2238209: 1}
# {6699836: 1}
# {4663681: 1}
# {6679663: 1}
# {5439519: 1}
# {11812868: 1}
# {8173470: 1}
# {13044761: 1}
# {1550130: 1}
# {4173773: 1}
# {5102129: 1}
# {5758257: 1}
# {12120132: 1}
# {1448873: 1}
# {2910392: 1}
# {8374095: 1}
# {1569141: 1}
# {8494005: 1}
# {8005488: 1}
# {8417893: 1}
# {8091924: 1}
# {7528585: 1}
# {5842904: 1}
# {8310284: 1}
# {11285795: 1}
# {11465325: 1}
# {5446429: 1}
# {8470711: 1}
# {10303396: 1}
# {10749378: 1}
# {11959797: 1}
# {1929189: 1}
# {10431863: 1}
# {6919266: 1}
# {7473388: 1}
# {10098783: 1}
# {10707223: 1}
# {8379332: 1}
# {7259408: 1}
# {10629106: 1}
# {2398851: 1}
# {12120132: 1}
# {8775396: 1}
# {9949842: 1}
# {6764085: 1}
# {5731131: 1}
# {11938874: 1}
# {8361898: 1}
# {3993974: 1}
# {9407286: 1}
# {205773: 1}
# {9093174: 1}
# {139750: 1}
# {1915296: 1}
# {10210340: 1}
# {9680615: 1}
# {4303026: 1}
# {6073054: 1}
# {9614992: 1}
# {11932487: 1}
# {7699771: 1}
# {2450986: 1}
# {3263726: 1}
# {8597848: 1}
# {11904951: 1}
# {883893: 1}
# {9607789: 1}
# {12048887: 1}
# {4036968: 1}
# {4526927: 1}
# {2830877: 1}
# {2129518: 1}
# {11558844: 1}
# {4562520: 1}
# {7027764: 1}
# {9492241: 1}
# {4652374: 1}
# {11522229: 1}
# {10178628: 1}
# {8162643: 1}
# {2873191: 1}
# {8069755: 1}
# {4676007: 1}
# {10287185: 1}
# {11291525: 1}
# {8729499: 1}
# {481287: 1}
# {634028: 1}
# {12070858: 1}
# {4003003: 1}
# {9265818: 1}
# {5648925: 1}
# {10590808: 1}
# {2721464: 1}
# {546199: 1}
# {1241693: 1}
# {9110463: 1}
# {10680499: 1}
# {12120132: 1}
# {381241: 1}
# {737187: 1}
# {6055048: 1}
# {5439958: 1}
# {2909961: 1}
# {1734752: 1}
# {5415946: 1}
# {9088911: 1}
# {8635001: 1}
# {6545475: 1}
# {8664340: 1}
# {3293106: 1}
# {7317370: 1}
# {7464975: 1}
# {8772698: 1}
# {10802921: 1}
# {3734658: 1}
# {7280689: 1}
# {2658382: 1}
# {569180: 1}
# {4842246: 1}
# {8985446: 1}
# {4810713: 1}
# {9814795: 1}
# {11392084: 1}
# {9963044: 1}
# {11146757: 1}
# {8625085: 1}
# {8821224: 1}
# {4810932: 1}
# {11461251: 1}
# {11033914: 1}
# {4679049: 1}
# {4963412: 1}
# {1444402: 1}
# {4665681: 1}
# {7688227: 1}
# {1713117: 1}
# {236046: 1}
# {5886962: 1}
# {9539771: 1}
# {10507713: 1}
# {1519447: 1}
# {2925223: 1}
# {10350246: 1}
# {7629202: 1}
# {6089259: 1}
# {7529688: 1}
# {13045325: 1}
# {7639621: 1}
# {11188846: 1}
# {3862772: 1}
# {5125191: 1}
# {11067621: 1}
# {10199984: 1}
# {2944964: 1}
# {11844090: 1}
# {9851112: 1}
# {9554793: 1}
# {8461726: 1}
# {1955056: 1}
# {10186400: 1}
# {11981488: 1}
# {6089604: 1}
# {10125159: 1}
# {5265319: 1}
# {10247491: 1}
# {5923298: 1}
# {5744230: 1}
# {708405: 1}
# {5412923: 1}
# {11950996: 1}
# {9977486: 1}
# {6435153: 1}
# {1784337: 1}
# {9197884: 1}
# {497694: 1}
# {5358970: 1}
# {9348384: 1}
# {10341782: 1}
# {6086114: 1}
# {7047219: 1}
# {10634664: 1}
# {11140901: 1}
# {9088911: 1}
# {5961887: 1}
# {10447755: 1}
# {10674758: 1}
# {4736085: 1}
# {10660857: 1}
# {6318834: 1}
# {2172964: 1}
# {8694806: 1}
# {11174505: 1}
# {2882105: 1}
# {7425687: 1}
# {1206671: 1}
# {2793591: 1}
# {926567: 1}
# {12241943: 1}
# {6782828: 1}
# {10133652: 1}
# {1357648: 1}
# {4411390: 1}
# {12186184: 1}
# {2499444: 1}
# {11882141: 1}
# {1573059: 1}
# {2908303: 1}
# {5486714: 1}
# {8888104: 1}
# {8049313: 1}
# {7403400: 1}
# {6452482: 1}
# {7986466: 1}
# {6170023: 1}
# {9008657: 1}
# {5364849: 1}
# {4970607: 1}
# {6719391: 1}
# {3461003: 1}
# {8716590: 1}
# {11478846: 1}
# {4267023: 1}
# {9789145: 1}
# {9630953: 1}
# {11097592: 1}
# {9068336: 1}
# {9154389: 1}
# {6273169: 1}
# {9601000: 1}
# {7807528: 1}
# {11945185: 1}
# {6129542: 1}
# {2035216: 1}
# {7755462: 1}
# {3757121: 1}
# {2850195: 1}
# {7501970: 1}
# {5473853: 1}
# {8961596: 1}
# {2869065: 1}
# {2461222: 1}
# {8218983: 1}
# {2759487: 1}
# {9295153: 1}
# {11694240: 1}
# {8639300: 1}
# {5186266: 1}
# {1739914: 1}
# {3971308: 1}
# {1708042: 1}
# {6305417: 1}
# {9728155: 1}
# {377344: 1}
# {12060891: 1}
# {682988: 1}
# {7400235: 1}
# {10629295: 1}
# {10282292: 1}
# {8296958: 1}
# {5798903: 1}
# {1177819: 1}
# {11901517: 1}
# {5031616: 1}
# {5885674: 1}
# {6545199: 1}
# {8161967: 1}
# {600272: 1}
# {5765666: 1}
# {10362496: 1}
# {7400421: 1}
# {7988074: 1}
# {11485815: 1}
# {5497794: 1}
# {3208233: 1}
# {12939789: 1}
# {2899506: 1}
# {10233625: 1}
# {1591390: 1}
# {8526847: 1}
# {203837: 1}
# {6025215: 1}
# {3459469: 1}
# {5606701: 1}
# {5243822: 1}
# {11890765: 1}
# {4094211: 1}
# {312962: 1}
# {11919055: 1}
# {12125355: 1}
# {4669856: 1}
# {1125740: 1}
# {3524171: 1}
# {9970389: 1}
# {6344771: 1}
# {6477660: 1}
# {5916340: 1}
# {9401444: 1}
# {7168685: 1}
# {8073778: 1}
# {4682439: 1}
# {1917343: 1}
# {23261: 1}
# {11701618: 1}
# {12926688: 1}
# {154991: 1}
# {4831465: 1}
# {10142813: 1}
# {1555693: 1}
# {6723849: 1}
# {7507547: 1}
# {867535: 1}
# {8263160: 1}
# {4819388: 1}
# {2064529: 1}
# {3498752: 1}
# {6501987: 1}
# {7398748: 1}
# {8135460: 1}
# {841421: 1}
# {7058952: 1}
# {6594601: 1}
# {10549730: 1}
# {6724365: 1}
# {2803500: 1}
# {10159769: 1}
# {9101212: 1}
# {12207856: 1}
# {8510803: 1}
# {11311292: 1}
# {8917578: 1}
# {13030189: 1}
# {9546813: 1}
# {1609201: 1}
# {5344352: 1}
# {8167295: 1}
# {12036065: 1}
# {3635385: 1}
# {3034797: 1}
# {2637156: 1}
# {11629601: 1}
# {8932534: 1}
# {7996080: 1}
# {11487238: 1}
# {3263387: 1}
# {7209470: 1}
# {11140901: 1}
# {8689847: 1}
# {4478794: 1}
# {5647366: 1}
# {4674626: 1}
# {10850051: 1}
# {12275915: 1}
# {10229584: 1}
# {795991: 1}
# {9755453: 1}
# {2957485: 1}
# {4480192: 1}
# {9249642: 1}
# {11419415: 1}
# {3099859: 1}
# {993501: 1}
# {11495815: 1}
# {949881: 1}
# {7230436: 1}
# {3869640: 1}
# {8536482: 1}
# {6830689: 1}
# {2461146: 1}
# {11560305: 1}
# {7021099: 1}
# {2011252: 1}
# {3585796: 1}
# {9830028: 1}
# {10898471: 1}
# {4853302: 1}
# {8630582: 1}
# {8941648: 1}
# {8764861: 1}
# {4641810: 1}
# {10195799: 1}
# {5138280: 1}
# {9092336: 1}
# {449821: 1}
# {10763850: 1}
# {21981: 1}
# {11757709: 1}
# {10222664: 1}
# {1281518: 1}
# {3201375: 1}
# {299059: 1}
# {7623229: 1}
# {11443464: 1}
# {9851922: 1}
# {8495126: 1}
# {5306940: 1}
# {9922389: 1}
# {9678503: 1}
# {11430507: 1}
# {6870236: 1}
# {737736: 1}
# {11359291: 1}
# {6502876: 1}
# {10763819: 1}
# {1511620: 1}
# {10629106: 1}
# {8947683: 1}
# {10325495: 1}
# {9615547: 1}
# {12942677: 1}
# {8924918: 1}
# {6453298: 1}
# {3113226: 1}
# {10328363: 1}
# {1182172: 1}
# {426956: 1}
# {7379957: 1}
# {6753780: 1}
# {5300682: 1}
# {6594355: 1}
# {4282176: 1}
# {2205078: 1}
# {4037216: 1}
# {4706029: 1}
# {5785633: 1}
# {12938735: 1}
# {8558164: 1}
# {9324338: 1}
# {4559137: 1}
# {10247388: 1}
# {4400823: 1}
# {855460: 1}
# {6315883: 1}
# {9417365: 1}
# {11860916: 1}
# {6077660: 1}
# {9920588: 1}
# {6021718: 1}
# {1963922: 1}
# {10803088: 1}
# {3314167: 1}
# {10339218: 1}
# {7056391: 1}
# {647616: 1}
# {229074: 1}
# {6725706: 1}
# {9284314: 1}
# {4368291: 1}
# {2038776: 1}
# {2714936: 1}
# {943546: 1}
# {7270904: 1}
# {10221312: 1}
# {12120132: 1}
# {6879113: 1}
# {12186184: 1}
# {5643358: 1}
# {7550926: 1}
# {10933210: 1}
# recommended for 3000 users
# {8772473: 1}
# {11060159: 1}
# {760487: 1}
# {7197895: 1}
# {8020606: 1}
# {9873939: 1}
# {7393891: 1}
# {4708875: 1}
# {3200349: 1}
# {9908113: 1}
# {4170945: 1}
# {10014352: 1}
# {8583901: 1}
# {5725936: 1}
# {4234624: 1}
# {9282811: 1}
# {6748550: 1}
# {2724688: 1}
# {9066518: 1}
# {11106205: 1}
# {4082739: 1}
# {1782999: 1}
# {7333701: 1}
# {5030978: 1}
# {11203131: 1}
# {6715793: 1}
# {6777892: 1}
# {11251506: 1}
# {347593: 1}
# {2962152: 1}
# {9244711: 1}
# {1747218: 1}
# {5878931: 1}
# {5254789: 1}
# {259777: 1}
# {9685085: 1}
# {8496184: 1}
# {10868663: 1}
# {4711910: 1}
# {3728455: 1}
# {7182927: 1}
# {9106759: 1}
# {4016523: 1}
# {8370909: 1}
# {229815: 1}
# {8612487: 1}
# {2390954: 1}
# {8940966: 1}
# {4961680: 1}
# {1600999: 1}
# {8941055: 1}
# {11078576: 1}
# {12907604: 1}
# {4815242: 1}
# {9960928: 1}
# {2589981: 1}
# {7864231: 1}
# {9058939: 1}
# {3579988: 1}
# {6794791: 1}
# {6427709: 1}
# {6350221: 1}
# {10252023: 1}
# {7263975: 1}
# {11281845: 1}
# {7308463: 1}
# {7118300: 1}
# {10527416: 1}
# {6237605: 1}
# {6007113: 1}
# {12120132: 1}
# {5974468: 1}
# {9722278: 1}
# {2722793: 1}
# {4552865: 1}
# {3302689: 1}
# {2784314: 1}
# {1343111: 1}
# {2894594: 1}
# {9625173: 1}
# {2081517: 1}
# {5647623: 1}
# {489647: 1}
# {707250: 1}
# {10260419: 1}
# {6661755: 1}
# {11581281: 1}
# {2082383: 1}
# {5236888: 1}
# {1706062: 1}
# {6970160: 1}
# {8716590: 1}
# {7298913: 1}
# {9833768: 1}
# {12022707: 1}
# {11529591: 1}
# {1930409: 1}
# {10462418: 1}
# {1039179: 1}
# {6427709: 1}
# {11584400: 1}
# {9911045: 1}
# {12120132: 1}
# {11986425: 1}
# {9576989: 1}
# {5610461: 1}
# {2147381: 1}
# {5274943: 1}
# {5894906: 1}
# {6744428: 1}
# {5201250: 1}
# {4869741: 1}
# {4231349: 1}
# {5367844: 1}
# {3416978: 1}
# {8247296: 1}
# {4727496: 1}
# {11608392: 1}
# {7122400: 1}
# {10905083: 1}
# {11457749: 1}
# {10208561: 1}
# {1209288: 1}
# {11797227: 1}
# {10201228: 1}
# {7646419: 1}
# {2729197: 1}
# {2115380: 1}
# {7790115: 1}
# {4834968: 1}
# {3074878: 1}
# {7098642: 1}
# {7840784: 1}
# {3218701: 1}
# {841421: 1}
# {830805: 1}
# {10567346: 1}
# {11661797: 1}
# {3282375: 1}
# {9112865: 1}
# {4749671: 1}
# {11867643: 1}
# {10597052: 1}
# {8442868: 1}
# {9856760: 1}
# {7236317: 1}
# {6189720: 1}
# {11361917: 1}
# {7427155: 1}
# {8455063: 1}
# {3479070: 1}
# {910387: 1}
# {10336760: 1}
# {9041374: 1}
# {8516373: 1}
# {2968534: 1}
# {12873908: 1}
# {3674695: 1}
# {13001164: 1}
# {5785274: 1}
# {9112610: 1}
# {10717161: 1}
# {6273718: 1}
# {616630: 1}
# {3639815: 1}
# {11271163: 1}
# {10483018: 1}
# {7537192: 1}
# {7559672: 1}
# {8616130: 1}
# {6303969: 1}
# {10298615: 1}
# {4529619: 1}
# {6362866: 1}
# {8230832: 1}
# {10691765: 1}
# {5051452: 1}
# {8442665: 1}
# {2954613: 1}
# {10328492: 1}
# {7969534: 1}
# {10420044: 1}
# {5895019: 1}
# {997901: 1}
# {3720006: 1}
# {8715839: 1}
# {5039704: 1}
# {8306463: 1}
# {5175546: 1}
# {9199261: 1}
# {749154: 1}
# {4876789: 1}
# {8952786: 1}
# {1111105: 1}
# {12120132: 1}
# {1949204: 1}
# {4517824: 1}
# {1110622: 1}
# {6504569: 1}
# {11570343: 1}
# {7990832: 1}
# {9649649: 1}
# {6858416: 1}
# {2631407: 1}
# {7003702: 1}
# {11324555: 1}
# {5561063: 1}
# {6754196: 1}
# {8187333: 1}
# {4987890: 1}
# {1927991: 1}
# {10775369: 1}
# {6316725: 1}
# {8510143: 1}
# {2998676: 1}
# {10060924: 1}
# {2822384: 1}
# {1359800: 1}
# {6721215: 1}
# {9923057: 1}
# {4717776: 1}
# {7987289: 1}
# {2752251: 1}
# {350497: 1}
# {4265180: 1}
# {11873675: 1}
# {9240416: 1}
# {7314970: 1}
# {10899166: 1}
# {5743652: 1}
# {1989441: 1}
# {11184374: 1}
# {4834091: 1}
# {2614685: 1}
# {5535123: 1}
# {8309737: 1}
# {6437206: 1}
# {6903064: 1}
# {8387680: 1}
# {12183808: 1}
# {12023799: 1}
# {5059646: 1}
# {8706266: 1}
# {10647449: 1}
# {10526180: 1}
# {11638981: 1}
# {7613720: 1}
# {6993598: 1}
# {8711266: 1}
# {8605555: 1}
# {3333761: 1}
# {6045409: 1}
# {9656648: 1}
# {3480809: 1}
# {10498730: 1}
# {10348105: 1}
# {5157259: 1}
# {1015232: 1}
# {10013593: 1}
# {3957062: 1}
# {5971301: 1}
# {11275322: 1}
# {8693075: 1}
# {11237628: 1}
# {7206072: 1}
# {9351190: 1}
# {9728631: 1}
# {11101436: 1}
# {8572869: 1}
# {6612376: 1}
# {9217134: 1}
# {9136384: 1}
# {11800193: 1}
# {2460043: 1}
# {10915353: 1}
# {7656747: 1}
# {8438829: 1}
# {7388700: 1}
# {5456443: 1}
# {6652879: 1}
# {2939643: 1}
# {4362713: 1}
# {4849006: 1}
# {10042158: 1}
# {12905528: 1}
# {5688644: 1}
# {11621056: 1}
# {5041107: 1}
# {814951: 1}
# {8234559: 1}
# {853217: 1}
# {13043427: 1}
# {4937491: 1}
# {5611991: 1}
# {5888973: 1}
# {1891275: 1}
# {6866700: 1}
# {6273545: 1}
# {11996530: 1}
# {8410869: 1}
# {11028065: 1}
# {5495331: 1}
# {9217134: 1}
# {10307545: 1}
# {8366262: 1}
# {5885476: 1}
# {1464146: 1}
# {2132711: 1}
# {9168043: 1}
# {11004115: 1}
# {9989366: 1}
# {5693710: 1}
# {6573858: 1}
# {11953345: 1}
# {5318587: 1}
# {7767498: 1}
# {6417751: 1}
# {11660391: 1}
# {3197494: 1}
# {10537223: 1}
# {4441022: 1}
# {10868663: 1}
# {9859789: 1}
# {10120244: 1}
# {10159702: 1}
# {7410089: 1}
# {8201009: 1}
# {2760638: 1}
# {1517661: 1}
# {1246708: 1}
# {2493538: 1}
# {8896752: 1}
# {11741594: 1}
# {11310757: 1}
# {10517552: 1}
# {124596: 1}
# {2081235: 1}
# {994534: 1}
# {1008729: 1}
# {3940811: 1}
# {10606414: 1}
# {8456569: 1}
# {6488429: 1}
# {7793992: 1}
# {5335537: 1}
# {8901938: 1}
# {2850195: 1}
# {1427586: 1}
# {2451528: 1}
# {4937034: 1}
# {7326920: 1}
# {4711527: 1}
# {6213902: 1}
# {6337303: 1}
# {4380016: 1}
# {5486252: 1}
# {9355180: 1}
# {5171696: 1}
# {5183548: 1}
# {12097559: 1}
# {5402549: 1}
# {11533456: 1}
# {9965060: 1}
# {10405165: 1}
# {7870540: 1}
# {11136835: 1}
# {10474533: 1}
# {2214827: 1}
# {2637896: 1}
# {4010839: 1}
# {7422537: 1}
# {831482: 1}
# {5362738: 1}
# {5526988: 1}
# {8178434: 1}
# {4711132: 1}
# {5306219: 1}
# {9946614: 1}
# {7292264: 1}
# {4299068: 1}
# {1715834: 1}
# {2226763: 1}
# {11840805: 1}
# {9136826: 1}
# {7087083: 1}
# {8124247: 1}
# {10155216: 1}
# {10754072: 1}
# {3120045: 1}
# {8842621: 1}
# {10946161: 1}
# {4327279: 1}
# {5747532: 1}
# {820168: 1}
# {2357979: 1}
# {5710554: 1}
# {6142807: 1}
# {887354: 1}
# {2723295: 1}
# {9350964: 1}
# {8764256: 1}
# {2782267: 1}
# {6814202: 1}
# {1882035: 1}
# {9805066: 1}
# {2777327: 1}
# {1054820: 1}
# {7760978: 1}
# {2029195: 1}
# {9238195: 1}
# {6088664: 1}
# {4059981: 1}
# {3504651: 1}
# {5820323: 1}
# {1988609: 1}
# {11845877: 1}
# {3713757: 1}
# {8515438: 1}
# {303481: 1}
# {8716590: 1}
# {7121655: 1}
# {445829: 1}
# {7881970: 1}
# {10533065: 1}
# {3285272: 1}
# {6900182: 1}
# {2413995: 1}
# {3747156: 1}
# {9021418: 1}
# {3617441: 1}
# {5143162: 1}
# {4866218: 1}
# {12667950: 1}
# {12954278: 1}
# {2610765: 1}
# {10916712: 1}
# {6141958: 1}
# {4059230: 1}
# {7102682: 1}
# {9944483: 1}
# {8484418: 1}
# {3015896: 1}
# {2259099: 1}
# {3600008: 1}
# {1370703: 1}
# {9323506: 1}
# {11873675: 1}
# {2993613: 1}
# {3776307: 1}
# {1678784: 1}
# {2479217: 1}
# {8694881: 1}
# {10483008: 1}
# {12157304: 1}
# {3629552: 1}
# {8483822: 1}
# {11019526: 1}
# {10921315: 1}
# {6185659: 1}
# {10525626: 1}
# {11732275: 1}
# {6475897: 1}
# {970737: 1}
# {2439565: 1}
# {5190265: 1}
# {4427303: 1}
# {10514876: 1}
# {7150192: 1}
# {12964888: 1}
# {547153: 1}
# {1407516: 1}
# {4125975: 1}
# {6994800: 1}
# {2073728: 1}
# {5618280: 1}
# {8952725: 1}
# {5415296: 1}
# {12060146: 1}
# {4019605: 1}
# {8116151: 1}
# {3206128: 1}
# {6593968: 1}
# {436466: 1}
# {9205435: 1}
# {453717: 1}
# {10723906: 1}
# {10980675: 1}
# {770769: 1}
# {5784301: 1}
# {1872991: 1}
# {10402380: 1}
# {7751971: 1}
# {11961247: 1}
# {6289161: 1}
# {3902625: 1}
# {9709192: 1}
# {7613920: 1}
# {10057219: 1}
# {3313474: 1}
# {5372298: 1}
# recommended for 3500 users
# {6767006: 1}
# {5052440: 1}
# {10163932: 1}
# {2689113: 1}
# {5341535: 1}
# {5393354: 1}
# {6220166: 1}
# {2049551: 1}
# {8821806: 1}
# {6291306: 1}
# {7718573: 1}
# {8959794: 1}
# {5209089: 1}
# {4316760: 1}
# {1769850: 1}
# {11339621: 1}
# {7533238: 1}
# {10871857: 1}
# {8189822: 1}
# {1780221: 1}
# {4790612: 1}
# {12038278: 1}
# {6462948: 1}
# {6104915: 1}
# {7989723: 1}
# {9201577: 1}
# {11873675: 1}
# {9349441: 1}
# {3936752: 1}
# {6728922: 1}
# {7110903: 1}
# {11717821: 1}
# {9621043: 1}
# {11581884: 1}
# {4731730: 1}
# {9858509: 1}
# {6561189: 1}
# {7057863: 1}
# {4406917: 1}
# {9352854: 1}
# {9515496: 1}
# {7528477: 1}
# {7042137: 1}
# ...
# {1638331: 1}
# {5671181: 1}
# {11340112: 1}
# {8444137: 1}
# {7014586: 1}
# {10287860: 1}
# {6340732: 1}
# {12462446: 1}
# {329698: 1}
# {12320326: 1}
# {2651158: 1}
# {2266928: 1}
# {12510957: 1}
# {1204874: 1}
# {9809765: 1}
# {11118151: 1}
# {12156864: 1}
# {7161518: 1}
# {624799: 1}
# {8002286: 1}
# {7913342: 1}
# {7406668: 1}
# {1669163: 1}
# {5192636: 1}
# {3555185: 1}
# {9968723: 1}
# {9531029: 1}
# {10521380: 1}
# {10868663: 1}
# {2802728: 1}
# {2603151: 1}
# {9186301: 1}
# {9856195: 1}
# {427545: 1}
# {2844103: 1}
# {8379404: 1}
# {5623784: 1}
# {4356620: 1}
# {10442878: 1}
# {1007290: 1}
# {8249436: 1}
# {12562153: 1}
# {11006068: 1}
# {1919088: 1}
# {6014420: 1}
# {11962581: 1}
# {2806589: 1}
# {1813684: 1}
# {8361014: 1}
# {10166752: 1}
# {5940388: 1}
# {7887196: 1}
# {9213350: 1}
# {7339122: 1}
# {498543: 1}
# {2408620: 1}
# {11015021: 1}
# {2817916: 1}
# {1693125: 1}
# {5436967: 1}
# {7448367: 1}
# {8481367: 1}
# {8711161: 1}
# {10601417: 1}
# {3866632: 1}
# {825847: 1}
# {10215606: 1}
# {7100576: 1}
# {8004377: 1}
# {9145605: 1}
# {7300571: 1}
# {666863: 1}
# {413344: 1}
# {5024001: 1}
# {7657128: 1}
# {11267406: 1}
# {12285268: 1}
# {4515006: 1}
# {6097521: 1}
# {4711069: 1}
# {5814951: 1}
# {2200004: 1}
# {6262103: 1}
# {7855175: 1}
# {10699486: 1}
# {3422277: 1}
# {8543967: 1}
# {2400534: 1}
# {2226393: 1}
# {11472682: 1}
# {6967194: 1}
# {7810764: 1}
# {4837160: 1}
# {10535933: 1}
# {8280604: 1}
# {4950362: 1}
# {7117009: 1}
# {7263975: 1}
# {10881372: 1}
# {8753413: 1}
# {2924843: 1}
# {2423200: 1}
# {1234968: 1}
# {2170013: 1}
# {11517492: 1}
# {5403105: 1}
# {12359568: 1}
# {3835818: 1}
# {402843: 1}
# {747917: 1}
# {1711144: 1}
# {4835736: 1}
# {9731668: 1}
# {7635849: 1}
# {9642033: 1}
# {5284283: 1}
# {2965199: 1}
# {6717721: 1}
# {5010551: 1}
# {7482936: 1}
# {1008302: 1}
# {6531791: 1}
# {10248354: 1}
# {12980730: 1}
# {10868663: 1}
# {457703: 1}
# {10382716: 1}
# {11917024: 1}
# {11680535: 1}
# {2498249: 1}
# {10568202: 1}
# {11593813: 1}
# {11680535: 1}
# {7218554: 1}
# {2802300: 1}
# {2165330: 1}
# {9087844: 1}
# {9824129: 1}
# {2249889: 1}
# {10525626: 1}
# {5811127: 1}
# {10278397: 1}
# {8551168: 1}
# {5024196: 1}
# {9306086: 1}
# {12980963: 1}
# {1013112: 1}
# {9885529: 1}
# {9971783: 1}
# {8573871: 1}
# {7979097: 1}
# {11786529: 1}
# {4907279: 1}
# {1867115: 1}
# {8477823: 1}
# {2258700: 1}
# {11236268: 1}
# {7979097: 1}
# {11472085: 1}
# {3748736: 1}
# {2211361: 1}
# {9614993: 1}
# {9413107: 1}
# {9907121: 1}
# {434722: 1}
# {11294609: 1}
# {12351508: 1}
# {12419011: 1}
# {4692602: 1}
# {8168694: 1}
# {9140198: 1}
# {7216986: 1}
# {7695133: 1}
# {10249578: 1}
# {10506774: 1}
# {128450: 1}
# {10574574: 1}
# {4783678: 1}
# {2022605: 1}
# {56627: 1}
# {8959536: 1}
# {2965146: 1}
# {11091094: 1}
# {9195807: 1}
# {8678839: 1}
# {1210235: 1}
# {7767525: 1}
# {9242513: 1}
# {11793879: 1}
# {7697028: 1}
# {12505832: 1}
# {10747560: 1}
# {2872559: 1}
# {8322581: 1}
# {5277240: 1}
# {468907: 1}
# {12404312: 1}
# {7095624: 1}
# {10260085: 1}
# {5028775: 1}
# {12123173: 1}
# {10657969: 1}
# {3261551: 1}
# {529283: 1}
# {1713496: 1}
# {11806940: 1}
# {9936047: 1}
# {8515413: 1}
# {9037090: 1}
# {10842483: 1}
# {5027976: 1}
# {10449995: 1}
# {12422180: 1}
# {12127301: 1}
# {11172936: 1}
# {8351549: 1}
# {11255689: 1}
# {8960888: 1}
# {7114113: 1}
# {10381628: 1}
# {11778830: 1}
# {5769739: 1}
# {8744402: 1}
# {6704193: 1}
# {9290605: 1}
# {10786409: 1}
# {3737169: 1}
# {9171902: 1}
# {3421402: 1}
# {10134993: 1}
# {11593333: 1}
# {2676263: 1}
# {10292742: 1}
# {2509148: 1}
# {10923159: 1}
# {57159: 1}
# {7124199: 1}
# {6072072: 1}
# {8116168: 1}
# {11845723: 1}
# {8730045: 1}
# {1486814: 1}
# {11661866: 1}
# recommended for 10500 users
# {12327675: 1}
# {1041314: 1}
# {10062897: 1}
# {4576118: 1}
# {6345598: 1}
# {2931912: 1}
# {536049: 1}
# {8855723: 1}
# {10899285: 1}
# {12289022: 1}
# {9601977: 1}
# {5144169: 1}
# {6472958: 1}
# {4287978: 1}
# {12287624: 1}
# {6077975: 1}
# {1136268: 1}
# {12997754: 1}
# {5396214: 1}
# {1888368: 1}
# {9443856: 1}
# {1186292: 1}
# {659132: 1}
# {4558728: 1}
# {10062267: 1}
# {10157647: 1}
# {11770992: 1}
# {4035139: 1}
# {9707041: 1}
# {8798895: 1}
# {7375076: 1}
# {8347543: 1}
# {1287212: 1}
# {12916916: 1}
# {12980730: 1}
# {5367112: 1}
# {9168391: 1}
# {12144660: 1}
# {3328043: 1}
# {10997682: 1}
# {9243418: 1}
# {2135737: 1}
# {7044546: 1}
# {5685874: 1}
# {5993839: 1}
# {2939158: 1}
# {6518653: 1}
# {12373223: 1}
# {1981395: 1}
# {3511403: 1}
# {8158395: 1}
# {2000407: 1}
# {9799399: 1}
# {484161: 1}
# {4311423: 1}
# {6071860: 1}
# {2704270: 1}
# {11559534: 1}
# {7698674: 1}
# {2902303: 1}
# {6487737: 1}
# {6096460: 1}
# {7431634: 1}
# {128: 1}
# {10752340: 1}
# {1366046: 1}
# {12532345: 1}
# {4115037: 1}
# {6287000: 1}
# {2735674: 1}
# {343034: 1}
# {7833755: 1}
# {3897473: 1}
# {4040363: 1}
# {9066792: 1}
# {11501258: 1}
# {746439: 1}
# {7471790: 1}
# {3418078: 1}
# {9560508: 1}
# {9433020: 1}
# {54814: 1}
# {11301995: 1}
# {4459138: 1}
# {10323097: 1}
# {8431377: 1}
# {6359001: 1}
# {8796027: 1}
# {6098147: 1}
# {3227771: 1}
# {3808269: 1}
# {7384316: 1}
# {8497727: 1}
# {182661: 1}
# {3408011: 1}
# {8322904: 1}
# {9943514: 1}
# {6342956: 1}
# {7431033: 1}
# {2432044: 1}
# {699487: 1}
# {2821282: 1}
# {9164207: 1}
# {7936790: 1}
# {9884086: 1}
# {4616784: 1}
# {6679963: 1}
# {5953637: 1}
# {8582654: 1}
# {5876141: 1}
# {340045: 1}
# {2086356: 1}
# {10515920: 1}
# {3944953: 1}
# {1066551: 1}
# {11301897: 1}
# {3110693: 1}
# {8768446: 1}
# {3311485: 1}
# {4646909: 1}
# {8254822: 1}
# {7302736: 1}
# {4405756: 1}
# {8950001: 1}
# {2283477: 1}
# {8105692: 1}
# {9743575: 1}
# {2870538: 1}
# {7312631: 1}
# {1198714: 1}
# {8186113: 1}
# {9577992: 1}
# {497842: 1}
# {6918302: 1}
# {5757130: 1}
# {12220210: 1}
# {8438806: 1}
# {2170013: 1}
# {4068908: 1}
# {9438613: 1}
# {8262536: 1}
# {8514376: 1}
# {1801055: 1}
# {4529589: 1}
# {5805500: 1}
# {12180127: 1}
# {7336232: 1}
# {427783: 1}
# {4770479: 1}
# {708287: 1}
# {4142048: 1}
# {2034916: 1}
# {7737258: 1}
# {10990508: 1}
# {11693609: 1}
# {4277234: 1}
# {4845453: 1}
# {12616685: 1}
# {6946607: 1}
# {11529830: 1}
# {9076372: 1}
# {8673319: 1}
# {3986132: 1}
# {945275: 1}
# {6347158: 1}
# {9162790: 1}
# {4858255: 1}
# {11122223: 1}
# {3932068: 1}
# {3762490: 1}
# {7489874: 1}
# {12020124: 1}
# {7758154: 1}
# {9539771: 1}
# {7050916: 1}
# {10611214: 1}
# {11187144: 1}
# {8933514: 1}
# {6014277: 1}
# {8037368: 1}
# {2420193: 1}
# {9732857: 1}
# {11536184: 1}
# {6482591: 1}
# {7458515: 1}
# {5197469: 1}
# {8716458: 1}
# {9422742: 1}
# {12332061: 1}
# {5122383: 1}
# {1414110: 1}
# {9574451: 1}
# {8914656: 1}
# {8931682: 1}
# {11979096: 1}
# {5248833: 1}
# {11945185: 1}
# {7806392: 1}
# {11085608: 1}
# {1508661: 1}
# {10476627: 1}
# {9288480: 1}
# {1702785: 1}
# {7626270: 1}
# {6904157: 1}
# {10845210: 1}
# {10379363: 1}
# {1095432: 1}
# {10875090: 1}
# {12194163: 1}
# {672511: 1}
# {6552802: 1}
# {211954: 1}
# {9610166: 1}
# {9923170: 1}
# {12639128: 1}
# {4162586: 1}
# {4719036: 1}
# {9088631: 1}
# {9222982: 1}
# {8869187: 1}
# {7227426: 1}
# {9170516: 1}
# {5893943: 1}
# {9775626: 1}
# {12581715: 1}
# {1202226: 1}
# {11750050: 1}
# {12631167: 1}
# {5020559: 1}
# {8266459: 1}
# {5881786: 1}
# {6661755: 1}
# {7134275: 1}
# {5033435: 1}
# {9831767: 1}
# {3280020: 1}
# {7239543: 1}
# {12441028: 1}
# {9755146: 1}
# {1619134: 1}
# {11883125: 1}
# {9480659: 1}
# {10317769: 1}
# {2940765: 1}
# {4970835: 1}
# {8164341: 1}
# {10748127: 1}
# {3564745: 1}
# {10679781: 1}
# {1972349: 1}
# {1117504: 1}
# {11948710: 1}
# {8572423: 1}
# {10345417: 1}
# {12434026: 1}
# {2171461: 1}
# {10917605: 1}
# {3090458: 1}
# {4242399: 1}
# {5830837: 1}
# {5265650: 1}
# {3872397: 1}
# {12358050: 1}
# {8647315: 1}
# {4031452: 1}
# {5510475: 1}
# {7240221: 1}
# {9926867: 1}
# {12569394: 1}
# {5489429: 1}
# {11830955: 1}
# {4970607: 1}
# {8733302: 1}
# {2475015: 1}
# {9535714: 1}
# {10655079: 1}
# {10129808: 1}
# {6163390: 1}
# {5347834: 1}
# {10914170: 1}
# {10171898: 1}
# {11264426: 1}
# {3628876: 1}
# {3784568: 1}
# {10444045: 1}
# {5640076: 1}
# {11747155: 1}
# {11659460: 1}
# {647443: 1}
# {6606921: 1}
# {6570413: 1}
# {2720828: 1}
# {5107293: 1}
# {2850195: 1}
# {3643003: 1}
# {2844726: 1}
# {4327330: 1}
# {3801666: 1}
# {3878638: 1}
# {10420734: 1}
# {7832138: 1}
# {11398361: 1}
# {10009547: 1}
# {8960043: 1}
# {8061746: 1}
# {10335604: 1}
# {7038793: 1}
# {2891551: 1}
# {5161830: 1}
# {11198853: 1}
# {10117452: 1}
# {5502642: 1}
# {5354854: 1}
# {3221912: 1}
# {2374489: 1}
# {9182625: 1}
# {11044689: 1}
# {11997643: 1}
# {866680: 1}
# {1246822: 1}
# {7341346: 1}
# {8292888: 1}
# {5745345: 1}
# {4454589: 1}
# {3965489: 1}
# {10382356: 1}
# {6796729: 1}
# {3293323: 1}
# {5243867: 1}
# {9194675: 1}
# {9940668: 1}
# {6490926: 1}
# {9786646: 1}
# {8501458: 1}
# {437206: 1}
# {8370692: 1}
# {6843799: 1}
# {9448544: 1}
# {5914789: 1}
# {934682: 1}
# {1901624: 1}
# {10752801: 1}
# {3216269: 1}
# {3566872: 1}
# {12979960: 1}
# {2690546: 1}
# {4879195: 1}
# {1211093: 1}
# {7496352: 1}
# {10216451: 1}
# {1198222: 1}
# {6819130: 1}
# {6918101: 1}
# {7133156: 1}
# {12147467: 1}
# {5126628: 1}
# {789348: 1}
# {8541874: 1}
# {6881987: 1}
# {6225047: 1}
# {7786542: 1}
# {4938367: 1}
# {3647096: 1}
# {7107651: 1}
# {6209419: 1}
# {9186113: 1}
# {7623499: 1}
# {8556319: 1}
# {673186: 1}
# {4867093: 1}
# {4047151: 1}
# {6935456: 1}
# {2881211: 1}
# {6857974: 1}
# {9306090: 1}
# {2341492: 1}
# {3934806: 1}
# {2850195: 1}
# {7478051: 1}
# {7750892: 1}
# {11316340: 1}
# {4896246: 1}
# {6146737: 1}
# {8048029: 1}
# {4664441: 1}
# {11445331: 1}
# {12354090: 1}
# {1587067: 1}
# {11273611: 1}
# {12002808: 1}
# {6176692: 1}
# {9829735: 1}
# {11272399: 1}
# {3386955: 1}
# {7259438: 1}
# {7465647: 1}
# {2081517: 1}
# {7503182: 1}
# {9072079: 1}
# {5172840: 1}
# {113683: 1}
# {592337: 1}
# {1374080: 1}
# {5637578: 1}
# {9515441: 1}
# {5765666: 1}
# {5244033: 1}
# {217025: 1}
# {3522728: 1}
# {10200616: 1}
# {7290248: 1}
# {1335152: 1}
# {10354937: 1}
# {6440011: 1}
# {11982035: 1}
# {10359968: 1}
# {1576768: 1}
# {10689940: 1}
# {9927629: 1}
# {3460068: 1}
# {10825197: 1}
# {10593821: 1}
# {10389154: 1}
# {9542789: 1}
# {4897439: 1}
# {11462355: 1}
# {6389940: 1}
# {2185396: 1}
# {9739999: 1}
# {8149349: 1}
# {9186383: 1}
# {6969060: 1}
# {9068609: 1}
# {11709774: 1}
# {8507873: 1}
# {5373623: 1}
# {9022366: 1}
# {10636676: 1}
# {9199924: 1}
# {7160925: 1}
# {6944208: 1}
# {11551996: 1}
# {6663030: 1}
# {7418933: 1}
# {3866632: 1}
# {1013112: 1}
# {4673431: 1}
# {871828: 1}
# {10702523: 1}
# {1527112: 1}
# {4193589: 1}
# {11018083: 1}
# {2316270: 1}
# {9816675: 1}
# {9558918: 1}
# {5096448: 1}
# {4732122: 1}
# {9299908: 1}
# {4569516: 1}
# {6866835: 1}
# {189045: 1}
# {3693374: 1}
# {10424369: 1}
# {5353866: 1}
# {1555732: 1}
# {5822606: 1}
# {2651158: 1}
# {7641524: 1}
# {13035117: 1}
# {7709098: 1}
# {12132370: 1}
# {5065683: 1}
# {6136710: 1}
# {5139263: 1}
# {275201: 1}
# {9326941: 1}
# {7665051: 1}
# {11242633: 1}
# {10408313: 1}
# {8221993: 1}
# {9879143: 1}
# {7550926: 1}
# {12165687: 1}
# {4979549: 1}
# {12029891: 1}
# {10516163: 1}
# {1245055: 1}
# {322324: 1}
# {8494149: 1}
# {13038480: 1}
# {7216068: 1}
# {10882204: 1}
# {13038480: 1}
# {4836573: 1}
# {9744688: 1}
# {1236538: 1}
# {955739: 1}
# {7871325: 1}
# {9892987: 1}
# recommended for 11000 users
# {5703163: 1}
# {2269871: 1}
# {12432059: 1}
# {9999995: 1}
# {2807401: 1}
# {2474050: 1}
# {11919819: 1}
# {6479778: 1}
# {1981395: 1}
# {6976650: 1}
# {2730908: 1}
# {5847270: 1}
# {7503671: 1}
# {6258329: 1}
# {2866550: 1}
# {5758356: 1}
# {6885517: 1}
# {5579407: 1}
# {1749018: 1}
# {4213471: 1}
# {12445539: 1}
# {4172832: 1}
# {307411: 1}
# {85472: 1}
# {8726885: 1}
# {1571892: 1}
# {8007634: 1}
# {1056022: 1}
# {325824: 1}
# {2891276: 1}
# {8293114: 1}
# {6249448: 1}
# {8988102: 1}
# {7959549: 1}
# {5990262: 1}
# {4630753: 1}
# {7864734: 1}
# {1177395: 1}
# {11292609: 1}
# {9096905: 1}
# {6425911: 1}
# {5848411: 1}
# {6348262: 1}
# {7390032: 1}
# {348263: 1}
# {5539681: 1}
# {657716: 1}
# {10547239: 1}
# {9124338: 1}
# {2798838: 1}
# {3412945: 1}
# {1711144: 1}
# {151444: 1}
# {4316635: 1}
# {9093926: 1}
# {2497938: 1}
# {8189913: 1}
# {10525626: 1}
# {1938165: 1}
# {9378623: 1}
# {3654649: 1}
# {10519710: 1}
# {2619793: 1}
# {4075440: 1}
# {10340905: 1}
# {517228: 1}
# {5988208: 1}
# {2140290: 1}
# {1502952: 1}
# {4935544: 1}
# {10371540: 1}
# {10136239: 1}
# {6142807: 1}
# {5472641: 1}
# {2402556: 1}
# {9037017: 1}
# {2500173: 1}
# {12474522: 1}
# {3246311: 1}
# {9473199: 1}
# {12458544: 1}
# {9857193: 1}
# {8109527: 1}
# {11735744: 1}
# {8337940: 1}
# {10656237: 1}
# {10010791: 1}
# {9763889: 1}
# {11523466: 1}
# {8582023: 1}
# {969444: 1}
# {296127: 1}
# {11421413: 1}
# {11205069: 1}
# {11695516: 1}
# {4732561: 1}
# {8090136: 1}
# {193063: 1}
# {12445503: 1}
# {11985672: 1}
# {8816559: 1}
# {10687363: 1}
# {11205743: 1}
# {8607931: 1}
# {9759428: 1}
# {4470476: 1}
# {8194156: 1}
# {8280758: 1}
# {12982818: 1}
# {4313372: 1}
# {1147187: 1}
# {9014964: 1}
# {10962709: 1}
# {8033128: 1}
# {9032807: 1}
# {6503219: 1}
# {12506178: 1}
# {11773807: 1}
# {11459382: 1}
# {12397305: 1}
# {6101680: 1}
# {6586988: 1}
# {9406240: 1}
# {7090311: 1}
# {1359800: 1}
# {10409718: 1}
# {10247690: 1}
# {11540760: 1}
# {9139686: 1}
# {5640894: 1}
# {7382810: 1}
# {12452181: 1}
# {8443024: 1}
# {1377721: 1}
# {3435727: 1}
# {518744: 1}
# {7554095: 1}
# {6352120: 1}
# {11821722: 1}
# {8713060: 1}
# {7610465: 1}
# {6114419: 1}
# {7970052: 1}
# {4834920: 1}
# {3866632: 1}
# {8180860: 1}
# {5970059: 1}
# {4192832: 1}
# {3921322: 1}
# {5859277: 1}
# {9315915: 1}
# {12080192: 1}
# {389866: 1}
# {4565521: 1}
# {9474158: 1}
# {4135962: 1}
# {33288: 1}
# {12602108: 1}
# {10783290: 1}
# {2429362: 1}
# {7564984: 1}
# {778310: 1}
# {11124939: 1}
# {8123849: 1}
# {4233017: 1}
# {483949: 1}
# {3071224: 1}
# {9497701: 1}
# {4386982: 1}
# {1246708: 1}
# {671722: 1}
# {8171200: 1}
# {2705825: 1}
# {3921488: 1}
# {12229147: 1}
# {10333295: 1}
# {1399036: 1}
# {3755584: 1}
# {8914604: 1}
# {2389271: 1}
# {7229375: 1}
# {2234448: 1}
# {7379458: 1}
# {3728970: 1}
# {12631628: 1}
# {6426586: 1}
# {11680535: 1}
# {1598786: 1}
# {7948407: 1}
# {7342199: 1}
# {7815308: 1}
# {7443898: 1}
# {4079829: 1}
# {10909089: 1}
# {3398880: 1}
# {6487631: 1}
# {6209711: 1}
# {1526570: 1}
# {1066551: 1}
# {9945081: 1}
# {9639105: 1}
# {12223765: 1}
# {2407173: 1}
# {10881319: 1}
# {5759401: 1}
# {9071100: 1}
# {9859309: 1}
# {6547607: 1}
# {10096979: 1}
# {78639: 1}
# {9589243: 1}
# {7169684: 1}
# {8604659: 1}
# {12108698: 1}
# {6116329: 1}
# {4420254: 1}
# {8913481: 1}
# {12575115: 1}
# {6943221: 1}
# {5415193: 1}
# {7626703: 1}
# {6889271: 1}
# {9061238: 1}
# {8128832: 1}
# {6428065: 1}
# {10797837: 1}
# {7411462: 1}
# {300144: 1}
# {8563648: 1}
# {1506121: 1}
# {9026910: 1}
# {5824406: 1}
# {3504275: 1}
# {4253473: 1}
# {1725594: 1}
# {12992413: 1}
# {5980744: 1}
# {11696076: 1}
# {6980453: 1}
# {7712790: 1}
# {3780580: 1}
# {4889127: 1}
# {689979: 1}
# {7854797: 1}
# {3647669: 1}
# {9628836: 1}
# {10450763: 1}
# {10712504: 1}
# {9002884: 1}
# {776482: 1}
# {1186021: 1}
# {3227771: 1}
# {5881175: 1}
# {5303414: 1}
# {2728879: 1}
# {2788914: 1}
# {6098415: 1}
# {5611975: 1}
# {4045428: 1}
# {234: 1}
# {6935052: 1}
# {7359774: 1}
# {11386929: 1}
# {731915: 1}
# {8043529: 1}
# {1281471: 1}
# {5620737: 1}
# {10657014: 1}
# {8290358: 1}
# {5096869: 1}
# {1326357: 1}
# {2222326: 1}
# {1119637: 1}
# {1847272: 1}
# {2201820: 1}
# {6262103: 1}
# {6472958: 1}
# {9764890: 1}
# {4623777: 1}
# {11727034: 1}
# {2724059: 1}
# {12183098: 1}
# {8567533: 1}
# {9351177: 1}
# {9901284: 1}
# {9710135: 1}
# {11714497: 1}
# {2305265: 1}
# {11520501: 1}
# {5301969: 1}
# {10463869: 1}
# {8875965: 1}
# {11291525: 1}
# {7686541: 1}
# {1326449: 1}
# {9773766: 1}
# {10566780: 1}
# {11422144: 1}
# {4642053: 1}
# {605040: 1}
# {6061697: 1}
# {8018555: 1}
# {1066551: 1}
# {8522127: 1}
# {2426357: 1}
# {9229838: 1}
# {5377330: 1}
# {10633963: 1}
# {6305848: 1}
# {10416451: 1}
# {8775387: 1}
# {12230251: 1}
# {1995947: 1}
# {10959614: 1}
# {13039609: 1}
# {6311323: 1}
# {6276522: 1}
# {7757294: 1}
# {7262301: 1}
# {7099997: 1}
# {850127: 1}
# {9123684: 1}
# {12959089: 1}
# {3866632: 1}
# {2249889: 1}
# {3442826: 1}
# {8115334: 1}
# {25661: 1}
# {3324231: 1}
# {1716127: 1}
# {707154: 1}
# {3082242: 1}
# {9948674: 1}
# {5900129: 1}
# {31555: 1}
# {9202621: 1}
# {9780863: 1}
# {11140901: 1}
# {11530893: 1}
# {1282472: 1}
# {12191880: 1}
# {2482585: 1}
# {8579396: 1}
# {9574451: 1}
# {11680535: 1}
# {1589650: 1}
# {394127: 1}
# {4164696: 1}
# {7245003: 1}
# {8531024: 1}
# {1366929: 1}
# {962753: 1}
# {3273839: 1}
# {10340195: 1}
# {9541613: 1}
# {5660937: 1}
# {12545299: 1}
# {12427182: 1}
# {5342214: 1}
# {523501: 1}
# {7421222: 1}
# {8726368: 1}
# {9517946: 1}
# {8259217: 1}
# {5694367: 1}
# {10939406: 1}
# {5271074: 1}
# {11008493: 1}
# {10033840: 1}
# {3519588: 1}
# {4678207: 1}
# {10140500: 1}
# {5748179: 1}
# {7846588: 1}
# {11555345: 1}
# {8607191: 1}
# {1261389: 1}
# {9248494: 1}
# {4536110: 1}
# {10897226: 1}
# {11538073: 1}
# {9470520: 1}
# {8557681: 1}
# {5073281: 1}
# {6663274: 1}
# {228626: 1}
# {8147122: 1}
# {9897114: 1}
# {7493135: 1}
# {2606747: 1}
# {2156012: 1}
# {7501440: 1}
# {9354413: 1}
# {9945946: 1}
# {6329034: 1}
# {5420789: 1}
# {11612688: 1}
# {12037837: 1}
# Predict end...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-2ae140eda9f8> in <module>
#       3 result_1 = itemcf_pred.predict()
#       4 result_1_df = pd.DataFrame(result_1,columns=['buyer_admin_id','rec_items'])
# ----> 5 result_1_df['rec_items'] = result_1_df.rec_users.apply(lambda x:[i[0] for i in x])
#       6 result_1_df['len'] = result_1_df.rec_users.apply(lambda x:len(x))
#       7 result_1_df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'rec_users'

# %%
result_1_df = pd.DataFrame(result_1,columns=['buyer_admin_id','rec_items'])
result_1_df['rec_items'] = result_1_df.rec_items.apply(lambda x:[i[0] for i in x])
result_1_df['len'] = result_1_df.rec_items.apply(lambda x:len(x))
result_1_df
# Out:
#        buyer_admin_id                                          rec_items  len
# 0             1061132  [271870, 1054046, 1122448, 2391739, 4072632, 7...   30
# 1             1081430  [4856217, 5682820, 7458004, 12126076, 12503254...   30
# 2             1918135  [6590471, 10885341, 11394392, 4836535, 7992644...   30
# 3              103277  [4645756, 10923142, 11593846, 11616639, 122735...   30
# 4             1957158  [2870878, 4885706, 5107224, 5285163, 9081706, ...   13
# 5             1376989  [3310805, 10557242, 6696523, 7816308, 2427684,...    7
# 6             1563046  [124429, 350514, 567140, 1690787, 1929729, 312...   30
# 7             1280264  [1031636, 5512544, 5971599, 8619743, 8722614, ...   30
# 8              104145  [3304800, 2394488, 5191519, 5091843, 9935350, ...   30
# 9              850637  [7451242, 8192508, 11460802, 5278123, 8548120,...   18
# 10            1135064  [8341121, 7999445, 530289, 690111, 950077, 202...   30
# 11            2302927  [98654, 7524993, 43845, 369371, 12669531, 2204...   30
# 12            1152117  [145801, 2286317, 3124863, 6459347, 7654516, 9...   29
# 13             570640  [98950, 4268204, 7922904, 11972920, 12272615, ...   30
# 14            1917676  [11924870, 7328327, 7991666, 3485334, 8667709,...   30
# 15            1944372  [9443952, 2336102, 3041418, 4097780, 9892793, ...   15
# 16             235457  [10229474, 9039964, 3080466, 5580796, 4347173,...   15
# 17            1746023  [11324642, 249333, 5267661, 5227978, 1418111, ...   30
# 18             406801  [4522268, 5836439, 11539192, 7549936, 7189989,...    7
# 19             230941  [4299237, 46324, 3917075, 1121966, 4124503, 63...   17
# 20            1553497  [12828, 92952, 5479963, 7519829, 9294376, 9577...   24
# 21             982049  [65843, 1695972, 3868967, 5481006, 9450218, 11...   30
# 22            1000927  [9837199, 9610161, 10258316, 5431814, 1810026,...   19
# 23             730501  [7975126, 4473366, 6289164, 5739083, 9537054, ...   14
# 24             135882  [1110389, 1114093, 5144128, 6813205, 6836902, ...   30
# 25             653027  [25309, 11456589, 3160200, 6413794, 1498809, 1...   30
# 26            2161973  [7691746, 9399332, 1962187, 158062, 8715636, 8...   10
# 27            1594372  [767909, 3339134, 7148921, 8227520, 11342896, ...   20
# 28             723249  [435064, 8314736, 4248858, 9545278, 6775093, 5...    6
# 29             503825  [10877112, 11164321, 9028593, 10279387, 120663...   30
# ...               ...                                                ...  ...
# 11368         1764504  [11880095, 978697, 10765527, 114199, 5463813, ...   10
# 11369         2203284  [1289908, 4498014, 5654852, 5729149, 2962192, ...   30
# 11370         1128243  [345495, 1605618, 10223625, 4905927, 3711891, ...   16
# 11371          847003  [8138175, 9517817, 9727712, 6926374, 9680617, ...   30
# 11372         2053089  [201890, 5692475, 7902419, 8278384, 7124818, 2...   10
# 11373         1439342  [1419885, 1744996, 6421582, 6647622, 12502099,...   19
# 11374         2212230  [12044880, 4503876, 12155114, 11527929, 118494...   13
# 11375          305285  [709181, 2485664, 4264647, 6032131, 7271915, 8...   30
# 11376          994361  [10016, 31457, 50668, 143931, 188817, 653944, ...   30
# 11377          960146  [1580759, 2551494, 4305977, 9646079, 1955633, ...   30
# 11378         2179759  [1660426, 3237982, 3901948, 4717193, 5466456, ...   30
# 11379         1785549  [596474, 3221202, 8519923, 8544812, 9853401, 1...   30
# 11380         2134165  [5432024, 127317, 5868529, 12235010, 570592, 3...   30
# 11381         2145746  [2281800, 3755727, 4393097, 4409368, 5001462, ...   30
# 11382          478657  [142902, 890503, 1797627, 2871069, 4537822, 65...   30
# 11383         1775754  [130117, 1217586, 1767746, 1783306, 1847723, 1...   30
# 11384          748015  [1494725, 2017961, 2908060, 7807540, 9048135, ...   30
# 11385          394913                                  [229420, 7192295]    2
# 11386          227724  [5208750, 5887932, 4661682, 4654998, 6668125, ...   12
# 11387         1283974  [953229, 11879818, 5971233, 870, 184803, 15962...   30
# 11388          385591  [552027, 1938428, 3662974, 7220067, 9893383, 1...   17
# 11389          524369  [1481904, 3102929, 3619540, 9879433, 10995395,...   26
# 11390         1688905  [1521483, 3569538, 2607053, 1698963, 11370444,...   30
# 11391         2361324  [1893512, 1523615, 1838060, 1961064, 4307722, ...   30
# 11392         1931205  [2503424, 4846316, 5126320, 6424789, 7717789, ...   30
# 11393          419958  [1540558, 3528731, 5040161, 5759658, 9405084, ...   30
# 11394         1242965  [6863355, 5864813, 1197459, 1194558, 6188307, ...    6
# 11395          962939  [757228, 1158938, 3581749, 9856601, 1592135, 2...   14
# 11396         1243416  [9514838, 623407, 11764488, 8931543, 3168640, ...    9
# 11397         2150916  [323427, 782074, 1437489, 1621085, 1651613, 22...   30
#
# [11398 rows x 3 columns]

# %%
import sys
import random
import math
import os
from operator import itemgetter
from collections import defaultdict

random.seed(44)

class ItemBasedCF(object):
    ''' TopN recommendation - Item Based Collaborative Filtering '''

    def __init__(self):
        self.trainset = {}
        self.testset = {}

        self.n_sim_item = 30  # 相似商品数
        self.n_rec_item = 30  # 推荐商品数

        self.item_sim_mat = {} 
        self.item_popular = {}
        self.item_count = 0

        print('Similar item number = %d' % self.n_sim_item)
        print('Recommended item number = %d' % self.n_rec_item)

    def generate_dataset(self, train, test=None, pivot=0.9):
        ''' load rating data and split it to training set and test set '''
        trainset_len = 0
        testset_len = 0
        if test is None:# 随机分配验证机实验 
            print('算法尝试！')
            for line in train.iterrows():
                user, item, rating = line[1][0],line[1][1],1
                # split the data by pivot
                if random.random() < pivot:
                    self.trainset.setdefault(user, {})
                    self.trainset[user][item] = int(rating)
                    trainset_len += 1
                else:
                    self.testset.setdefault(user, {})
                    self.testset[user][item] = int(rating)
                    testset_len += 1
        else:
            print('预测！')
            for line in train.iterrows():
                user, item, rating = line[1][0],line[1][1],1
                # split the data by pivot
                self.trainset.setdefault(user, {})
                self.trainset[user][item] = int(rating)
                trainset_len += 1
            del user,item,rating
            for line in test.iterrows():
                user, item, rating = line[1][0],line[1][1],1
                self.testset.setdefault(user, {})
                self.testset[user][item] = int(rating)
                testset_len += 1
            
        print ('split training set and test set succ')
        print ('train set = %s' % trainset_len)
        print ('test set = %s' % testset_len)

    def calc_item_sim(self):
        ''' calculate item similarity matrix '''
        print('counting items number and popularity...')
        for user, items in self.trainset.items():
            for item in items:
                # count item popularity
                if item not in self.item_popular:
                    self.item_popular[item] = 0
                self.item_popular[item] += 1

        print('count items number and popularity succ')
        # save the total number of items
        self.item_count = len(self.item_popular)
        print('total item number = %d' % self.item_count)

        # count co-rated users between items
        itemsim_mat = self.item_sim_mat
        print('building co-rated users matrix...')
        for user, items in self.trainset.items():
            for m1 in items:
                itemsim_mat.setdefault(m1, defaultdict(int))
                for m2 in items:
                    if m1 == m2:
                        continue
                    itemsim_mat[m1][m2] += 1
        print('build co-rated users matrix succ')

        # calculate similarity matrix
        print('calculating item similarity matrix...')
        simfactor_count = 0
        PRINT_STEP = 2000000

        for m1, related_items in itemsim_mat.items():
            for m2, count in related_items.items():
                itemsim_mat[m1][m2] = count / math.sqrt(
                    self.item_popular[m1] * self.item_popular[m2])
                simfactor_count += 1
                if simfactor_count % PRINT_STEP == 0:
                    print('calculating item similarity factor(%d)' %
                          simfactor_count)

        print('calculate item similarity matrix(similarity factor) succ')
        print('Total similarity factor number = %d' % simfactor_count)

    def recommend(self, user, predict=False):
        ''' Find K similar items and recommend N items. '''
        K = self.n_sim_item
        N = self.n_rec_item
        rank = {}
        if not predict:
            watched_items = self.trainset[user]
        else:
            watched_items = self.testset[user]
            
        print(watched_items)

        for item, rating in watched_items.items():
            if self.item_sim_mat.get(item,None) is None:
                continue
            for related_item, similarity_factor in sorted(self.item_sim_mat[item].items(),
                                                           key=itemgetter(1), reverse=True)[:K]:
                if related_item in watched_items:
                    continue
                rank.setdefault(related_item, 0)
                rank[related_item] += similarity_factor * rating
        # return the N best items
        return sorted(rank.items(), key=itemgetter(1), reverse=True)[:N]

    def evaluate(self):
        ''' print evaluation result: precision, recall, coverage and popularity '''
        print('Evaluation start...')

        N = self.n_rec_item
        #  varables for precision and recall
        hit = 0
        rec_count = 0
        test_count = 0
        # varables for coverage
        all_rec_items = set()
        # varables for popularity
        popular_sum = 0

        for i, user in enumerate(self.trainset):
            if i % 500 == 0:
                print ('recommended for %d users' % i)
            test_items = self.testset.get(user, {})
            rec_items = self.recommend(user)
            for item, _ in rec_items:
                if item in test_items:
                    hit += 1
                all_rec_items.add(item)
                popular_sum += math.log(1 + self.item_popular[item])
            rec_count += N
            test_count += len(test_items)

        precision = hit / (1.0 * rec_count)
        recall = hit / (1.0 * test_count)
        coverage = len(all_rec_items) / (1.0 * self.item_count)
        popularity = popular_sum / (1.0 * rec_count)

        print ('precision=%.4f\trecall=%.4f\tcoverage=%.4f\tpopularity=%.4f' %
               (precision, recall, coverage, popularity))
    
    def predict(self):
        print('Predict start...')

        N = self.n_rec_item
        #  varables for precision and recall
        hit = 0
        rec_count = 0
        test_count = 0
        # varables for coverage
        all_rec_items = set()
        # varables for popularity
        popular_sum = 0
        predict_result=[]
        for i, user in enumerate(self.testset):
            if i % 500 == 0:
                print ('recommended for %d users' % i)
            rec_items = self.recommend(user, predict=True)
            predict_result.append((user,rec_items))
        print('Predict end...')
        return predict_result
